# %%
from wrapper import *
import MahjongPy as mp
import os
import time
import logging
import warnings

import numpy as np
import scipy.io as sio
import torch
import matplotlib.pyplot as plt

import mahjong
from mahjong.shanten import Shanten

from models import VLOG

# %%
player_i_hand_start_ind = [0, 63, 69, 75]  # later 3 in oracle_obs
player_i_side_start_ind = [6, 12, 18, 24]
player_i_river_start_ind = [30, 37, 44, 51]

dora_indicator_ind = 58
dora_ind = 59
game_wind_ind = 60
self_wind_ind = 61
latest_tile_ind = 62

aka_tile_ints = [16, 16 + 36, 16 + 36 + 36]
player_obs_width = 63

CHILEFT = 34
CHIMIDDLE = 35
CHIRIGHT = 36
PON = 37
ANKAN = 38
MINKAN = 39
ADDKAN = 40

RIICHI = 41
RON = 42
TSUMO = 43
PUSH = 44
PASS_RESPONSE = 45
PASS_RIICHI = 46

# %%
UNICODE_TILES = """
    🀇 🀈 🀉 🀊 🀋 🀌 🀍 🀎 🀏 
    🀙 🀚 🀛 🀜 🀝 🀞 🀟 🀠 🀡
    🀐 🀑 🀒 🀓 🀔 🀕 🀖 🀗 🀘
    🀀 🀁 🀂 🀃
    🀆 🀅 🀄
""".split()

EXPLAINS = UNICODE_TILES + ["Chi-Left", "Chi-Middle", "Chi-Right", "Pon", "An-Kan",
           "Min-Kan", "Add-Kan", "Riichi", "Ron", "Tsumo", "Push 99", "Pass", "Pass"]

shanten = Shanten()

def to_unicode_tails(tiles, sort=True):
    unicode_tail_string = ""
    if sort:
        tiles = np.sort(np.array(tiles))

    for tile in tiles:
        unicode_tail_string = unicode_tail_string + UNICODE_TILES[int(tile / 4)]

    return unicode_tail_string

# %%
env_test = EnvMahjong3(force_riichi=True, force_win=False, append_aval_action_obs=True)
max_steps = 1000

# %%
# agent_test0 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_0.model")
# agent_test1 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_1.model")
# agent_test2 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_2.model")
# agent_test = torch.load("./vlog_offlinemj_20210724/search_envid_1_beta_0_alpha_1_kldt_-1_cqla_100/data/mahjong_VLOG_DDQN_0.model")


if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"


# agent_test0 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test1 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))
# agent_test2 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test3 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))

# agent_test0 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test1 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))
# agent_test2 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_0_alpha_1_kldt_-1_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_2.model", map_location=torch.device(device))
# agent_test3 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_0_alpha_1_kldt_-1_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_3.model", map_location=torch.device(device))


agent_test0 = torch.load("./vlog_offlinemj_cql_20210808/search_envid_1_beta_0_alpha_1_kldt_-1_bnt_0_dpo_0_eqn_0_cqla_300/data/mahjong_VLOG_DDQN_3.model", map_location=torch.device(device))
agent_test1 = torch.load("./vlog_offlinemj_cql_20210808/search_envid_1_beta_0_alpha_1_kldt_-1_bnt_0_dpo_0_eqn_0_cqla_300/data/mahjong_VLOG_DDQN_3.model", map_location=torch.device(device))
agent_test2 = torch.load("./vlog_offlinemj_cql_20210809/search_envid_1_beta_0_alpha_1_kldt_-1_bnt_0_dpo_0_eqn_0_cqla_5/data/mahjong_VLOG_DDQN_2.model", map_location=torch.device(device))
agent_test3 = torch.load("./vlog_offlinemj_cql_20210809/search_envid_1_beta_1e-08_alpha_1_kldt_30_bnt_0_dpo_0_eqn_0_cqla_5/data/mahjong_VLOG_DDQN_2.model", map_location=torch.device(device))

# %%
agents_test = [agent_test0, agent_test1, agent_test2, agent_test3]

for agent in agents_test:
    agent.device = device

# %%
full_obs = False

EpiTestRet = 0
steps_taken = 0

tsumo_times = np.array([0, 0, 0, 0])
liuju_times = 0
noten_times = 0
houjyu_times = np.array([0, 0, 0, 0])
riichi_times = np.array([0, 0, 0, 0])

riichi_agari_times = np.array([0, 0, 0, 0])
yami_agari_times = np.array([0, 0, 0, 0])

not_riichi_houjyu_times = np.array([0, 0, 0, 0])

fulu_times = np.array([0, 0, 0, 0])
agari_turns = np.array([0, 0, 0, 0])
agari_times = np.array([0, 0, 0, 0])

agari_scores = np.array([0, 0, 0, 0])
total_results = []

game = 0

# %%
import numpy

# %%
while game < 200000:
    print("==============================Game {}=============================".format(game))
    # reset each episode
    if game % 10 == 1:
        try:
            print("------------------------- Statistics ----------------------")
            print("平均结果:   ", numpy.array2string((np.mean(np.array(total_results), axis=0)), precision=3, separator=',    ', formatter={'float_kind':lambda x: "%5.2f" % x}))
            print("结果M.S.E.  ", numpy.array2string((np.array(total_results).std(axis=0) / np.sqrt(game)), precision=3, separator=',    ', formatter={'float_kind':lambda x: "%5.2f" % x}))
            print("自摸率：    ", numpy.array2string(tsumo_times * 100 / agari_times, precision=3, separator=',    ', formatter={'float_kind':lambda x: "%5.2f" % x}))
            print("放铳率：    ", numpy.array2string(houjyu_times * 100 / game, precision=3, separator=',    ', formatter={'float_kind':lambda x: "%5.2f" % x}))
            print("和了率：    ", numpy.array2string(agari_times * 100 / game, precision=3, separator=',    '))
            print("副露率：    ", numpy.array2string(fulu_times * 100 / game, precision=3, separator=',    '))
            print("立直率：    ", numpy.array2string(riichi_times * 100 / game, precision=3, separator=',    '))
            print("立直成功率： ", numpy.array2string(riichi_agari_times * 100 / riichi_times, precision=3, separator=',    '))
            print("暗和率：    ", numpy.array2string(yami_agari_times  * 100/ agari_times, precision=3, separator=',    '))
            print("平均打点：  ", numpy.array2string(agari_scores / agari_times, precision=0, separator=',    '))
            print("没立铳率：  ", numpy.array2string(not_riichi_houjyu_times * 100 / (game - riichi_times), precision=3, separator=',    '))
            print("平均和牌时还剩几张牌：", numpy.array2string(agari_turns / agari_times, precision=3, separator=',    '))
            print("流局率：    ", numpy.array2string((game - np.sum(agari_times)) * 100 / game, precision=3, separator=',    '))
            print("四家无听流局率： ", noten_times * 100 / game)
        except:
            pass
    try:
        sp = env_test.reset(game % 4, 'east')
        result_array = np.zeros([4])
        done = False
        has_riichi = [False] * 4

        for tt in range(max_steps):

            # if curr_pid != 0:
            #     a = valid_actions[np.random.randint(len(valid_actions))]

            valid_actions = env_test.get_valid_actions(nhot=False)

            if len(valid_actions) == 1:
                env_test.t.make_selection(0)

            else:
                curr_pid = env_test.get_curr_player_id()

                action_mask = env_test.get_valid_actions(nhot=True)

                if not full_obs:
                    a = agents_test[curr_pid].select(env_test.get_obs(curr_pid), action_mask, greedy=True)
                else:
                    a = agents_test[curr_pid].select(env_test.get_full_obs(curr_pid), action_mask, greedy=True)


#                 if a == TSUMO:
#                     print(env_test.get_full_obs(0)[player_i_river_start_ind[curr_pid]:player_i_river_start_ind[curr_pid] + 7,  int(env_test.latest_tile / 4)])
#                     plt.pcolor(env_test.get_obs(curr_pid))
#                     plt.show()

#                 if curr_pid == 0 and len(valid_actions) > 1:
#                     print("-------------- Step {}, player {} ----------------".format(tt, curr_pid))
#                     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
#                     side_tiles_0 = [st[0] for st in env_test.side_tiles[curr_pid]]
#                     print("手牌: ", to_unicode_tails(env_test.hand_tiles[curr_pid]),
#                           "； 副露：", to_unicode_tails(side_tiles_0))
#                     if a < 34:
#                         agent_selection_str = UNICODE_TILES[a]
#                     else:
#                         agent_selection_str = EXPLAINS[a]
                
#                     print("Agent选择打: ", agent_selection_str)

                sp, r, done, _ = env_test.step(curr_pid, a)
                if r < 0 and not done:
                    result_array[curr_pid] += r * 100
                
                    if r == -10:
                        riichi_times[curr_pid] += 1
                        has_riichi[curr_pid] = True
            
            steps_taken += 1

            if done or env_test.t.get_phase() == 16:
                
                payoffs = env_test.get_payoffs()
                # EpiTestRet += payoffs[0]
                result_array += np.array(payoffs) * 100
                print("~~~~~~~~~~~~Result: ", env_test.t.get_result().result_type, payoffs)
#                 print("remaining tiles:", env_test.t.get_remain_tile())
                total_results.append(result_array)
                for uid in range(4):
                    if len(env_test.side_tiles[uid]) >= 3:
                        fulu_times[uid] += 1
                
                if env_test.t.get_remain_tile() == 0:
                    liuju_times += 1
                    if np.max(payoffs) == 0:
                        noten_times += 1
                
                if env_test.t.get_remain_tile() > 0 and np.max(payoffs) > 0:  # not 流局
                    win_uid = np.argmax(payoffs)
                    agari_turns[win_uid] += env_test.t.get_remain_tile()
                    if has_riichi[win_uid]:
                        riichi_agari_times[win_uid] += 1
                    else:
                        yami_agari_times[win_uid] += 1
                    
                    if np.count_nonzero(result_array < 0) == 3:
                        tsumo_times[win_uid] += 1
                    else:
                        houjyu_times[np.argmin(result_array)] += 1
                        if not has_riichi[np.argmin(result_array)]:
                            not_riichi_houjyu_times[np.argmin(result_array)] += 1
                        
                    agari_times[win_uid] += 1
                    agari_scores[win_uid] += np.max(result_array)
                    
#                     win_pid = np.argmax(result_array)
#                     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
#                     side_tiles_0 = [st[0] for st in env_test.side_tiles[win_pid]]
#                     print("手牌: ", to_unicode_tails(env_test.hand_tiles[win_pid]),
#                           "； 副露：", to_unicode_tails(side_tiles_0))

                # print(env_test.t.game_log.to_string())
#                 if np.max(payoffs) > 0:
#                     plt.pcolor(sp)
#                     plt.show()
#                     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
#                     side_tiles_0 = [st[0] for st in env_test.side_tiles[np.argmax(payoffs)]]
#                     print("手牌: ", to_unicode_tails(env_test.hand_tiles[np.argmax(payoffs)]),
#                       "； 副露：", to_unicode_tails(side_tiles_0))
                break

#             if not done and env_test.t.get_phase() == 0:
#                 shanten_num = np.zeros(4)
#                 for pid in range(4):
#                     shanten_num[pid] = shanten.calculate_shanten(TilesConverter.to_34_array(
#                         env_test.hand_tiles[pid] + [st[0] for st in env_test.side_tiles[pid]]))
#                 print("向听数:", shanten_num)
        game += 1

    except Exception as e:
        print(e)
        if a < 34:
            agent_selection_str = UNICODE_TILES[a]
        else:
            agent_selection_str = EXPLAINS[a]
        print("Agent选择打: ", a)
        time.sleep(0.1)
        continue
# Out:
# ==============================Game 73=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-36.0, 128.0, -36.0, -36.0]
# ==============================Game 74=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-30.0, 10.0, 10.0, 10.0]
# ==============================Game 75=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -20.0, 70.0]
# ==============================Game 76=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -3.0, -3.0, 21.0]
# ==============================Game 77=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 35.0, -15.0, 0.0]
# ==============================Game 78=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 79=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-3.0, 11.0, -3.0, -5.0]
# ==============================Game 80=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [40.0, -10.0, -10.0, -10.0]
# ==============================Game 81=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-281.48,    -48.15,    -796.30,    767.90]
# 结果M.S.E.   [351.74,    363.82,    373.92,    493.54]
# 自摸率：     [46.15,    42.11,    88.89,    88.24]
# 放铳率：     [ 2.47,     8.64,    13.58,     1.23]
# 和了率：     [16.049,    23.457,    11.111,    20.988]
# 副露率：     [30.864,    34.568,    23.457,    45.679]
# 立直率：     [27.16 ,    28.395,    22.222,    19.753]
# 立直成功率：  [13.636,    34.783,    27.778,    43.75 ]
# 暗和率：     [76.923,    57.895,    44.444,    58.824]
# 平均打点：   [4162.,    4237.,    5867.,    6882.]
# 没立铳率：   [ 1.695,    10.345,    15.873,     1.538]
# 平均和牌时还剩几张牌： [23.846,    25.053,    32.556,    24.941]
# 流局率：     28.395
# 四家无听流局率：  1.2345679012345678
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 90.0, -80.0]
# ==============================Game 82=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -39.0, 89.0]
# ==============================Game 83=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, 79.0, -39.0]
# ==============================Game 84=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [39.0, -29.0, 0.0, 0.0]
# ==============================Game 85=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -10.0, 20.0, -5.0]
# ==============================Game 86=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, 30.0, -10.0, -5.0]
# ==============================Game 87=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 88=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -5.0, 40.0, -5.0]
# ==============================Game 89=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -39.0, -20.0, 89.0]
# ==============================Game 90=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, 80.0, -20.0]
# ==============================Game 91=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-345.05,    -172.53,    -494.51,    671.43]
# 结果M.S.E.   [318.58,    333.47,    373.84,    470.69]
# 自摸率：     [42.86,    45.00,    85.71,    89.47]
# 放铳率：     [ 2.20,     8.79,    12.09,     2.20]
# 和了率：     [15.385,    21.978,    15.385,    20.879]
# 副露率：     [30.769,    36.264,    23.077,    42.857]
# 立直率：     [28.571,    27.473,    23.077,    19.78 ]
# 立直成功率：  [15.385,    32.   ,    38.095,    44.444]
# 暗和率：     [71.429,    60.   ,    42.857,    57.895]
# 平均打点：   [4071.,    4175.,    5764.,    7042.]
# 没立铳率：   [ 1.538,    10.606,    14.286,     2.74 ]
# 平均和牌时还剩几张牌： [23.429,    24.3  ,    29.857,    25.526]
# 流局率：     26.374
# 四家无听流局率：  1.098901098901099
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [107.0, -77.0, 0.0, 0.0]
# ==============================Game 92=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [118.0, -36.0, -36.0, -36.0]
# ==============================Game 93=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [77.0, -77.0, 0.0, 0.0]
# ==============================Game 94=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 95=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [130.0, -30.0, -30.0, -60.0]
# ==============================Game 96=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -5.0, -5.0, 30.0]
# ==============================Game 97=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, 40.0, -10.0, -10.0]
# ==============================Game 98=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-40.0, -40.0, 130.0, -40.0]
# ==============================Game 99=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -3.0, -3.0, -5.0]
# ==============================Game 100=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -3.0, -3.0, 11.0]
# ==============================Game 101=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [ 8.91,    -379.21,    -427.72,    481.19]
# 结果M.S.E.   [355.62,    328.48,    361.18,    434.40]
# 自摸率：     [47.37,    47.62,    86.67,    90.48]
# 放铳率：     [ 1.98,     9.90,    10.89,     1.98]
# 和了率：     [18.812,    20.792,    14.851,    20.792]
# 副露率：     [30.693,    37.624,    23.762,    41.584]
# 立直率：     [29.703,    25.743,    21.782,    20.792]
# 立直成功率：  [23.333,    30.769,    40.909,    42.857]
# 暗和率：     [63.158,    61.905,    40.   ,    57.143]
# 平均打点：   [5174.,    4167.,    6180.,    6519.]
# 没立铳率：   [ 1.408,    10.667,    12.658,     2.5  ]
# 平均和牌时还剩几张牌： [22.789,    23.19 ,    30.333,    26.667]
# 流局率：     24.752
# 四家无听流局率：  0.9900990099009901
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-30.0, 10.0, 10.0, 10.0]
# ==============================Game 102=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [39.0, -39.0, 0.0, 0.0]
# ==============================Game 103=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 104=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 62.0, -52.0, 0.0]
# ==============================Game 105=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -5.0, -3.0, -3.0]
# ==============================Game 106=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-30.0, 10.0, 10.0, 10.0]
# ==============================Game 107=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -3.0, -3.0, -5.0]
# ==============================Game 108=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 109=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [10.0, -10.0, 0.0, 0.0]
# ==============================Game 110=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -10.0, -20.0, 60.0]
# ==============================Game 111=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [22.52,    -345.05,    -472.97,    471.17]
# 结果M.S.E.   [328.54,    305.35,    332.95,    398.06]
# 自摸率：     [47.83,    45.45,    86.67,    90.91]
# 放铳率：     [ 1.80,    10.81,    10.81,     1.80]
# 和了率：     [20.721,    19.82 ,    13.514,    19.82 ]
# 副露率：     [31.532,    37.838,    25.225,    41.441]
# 立直率：     [27.027,    26.126,    21.622,    20.721]
# 立直成功率：  [23.333,    31.034,    37.5  ,    43.478]
# 暗和率：     [69.565,    59.091,    40.   ,    54.545]
# 平均打点：   [4583.,    4214.,    6180.,    6450.]
# 没立铳率：   [ 1.235,    12.195,    12.644,     2.273]
# 平均和牌时还剩几张牌： [23.174,    22.273,    30.333,    25.636]
# 流局率：     26.126
# 四家无听流局率：  1.8018018018018018
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 112=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, -30.0, 10.0, 10.0]
# ==============================Game 113=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 26.0, -26.0]
# ==============================Game 114=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [49.0, -39.0, 0.0, 0.0]
# ==============================Game 115=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, 15.0, -15.0]
# ==============================Game 116=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 117=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, 10.0, 10.0, -30.0]
# ==============================Game 118=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, 30.0, -10.0, -5.0]
# ==============================Game 119=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 120=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 23.0, -13.0, 0.0]
# ==============================Game 121=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [61.16,    -366.94,    -427.27,    361.16]
# 结果M.S.E.   [305.95,    285.83,    307.50,    368.11]
# 自摸率：     [45.83,    45.83,    81.25,    90.91]
# 放铳率：     [ 1.65,    10.74,    10.74,     2.48]
# 和了率：     [19.835,    19.835,    13.223,    18.182]
# 副露率：     [32.231,    36.364,    23.967,    40.496]
# 立直率：     [27.273,    26.446,    23.967,    19.835]
# 立直成功率：  [21.212,    31.25 ,    31.034,    41.667]
# 暗和率：     [70.833,    58.333,    43.75 ,    54.545]
# 平均打点：   [4596.,    4042.,    5956.,    6450.]
# 没立铳率：   [ 1.136,    11.236,    11.957,     3.093]
# 平均和牌时还剩几张牌： [22.667,    22.083,    30.812,    25.636]
# 流局率：     28.926
# 四家无听流局率：  1.6528925619834711
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-30.0, -60.0, 130.0, -30.0]
# ==============================Game 122=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [20.0, -10.0, 0.0, 0.0]
# ==============================Game 123=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [50.0, -10.0, -10.0, -20.0]
# ==============================Game 124=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [69.0, -39.0, 0.0, 0.0]
# ==============================Game 125=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-40.0, -80.0, -40.0, 170.0]
# ==============================Game 126=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 127=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 36.0, -26.0]
# ==============================Game 128=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, 20.0, -5.0, -5.0]
# ==============================Game 129=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 130=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [21.0, -3.0, -5.0, -3.0]
# ==============================Game 131=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [79.39,    -500.76,    -321.37,    383.97]
# 结果M.S.E.   [291.66,    276.69,    301.96,    363.06]
# 自摸率：     [46.43,    48.00,    77.78,    91.30]
# 放铳率：     [ 1.53,    11.45,     9.92,     3.05]
# 和了率：     [21.374,    19.084,    13.74 ,    17.557]
# 副露率：     [31.298,    35.115,    24.427,    39.695]
# 立直率：     [26.718,    26.718,    25.191,    19.847]
# 立直成功率：  [25.714,    28.571,    33.333,    42.308]
# 暗和率：     [67.857,    60.   ,    38.889,    52.174]
# 平均打点：   [4439.,    3960.,    6106.,    6865.]
# 没立铳率：   [ 1.042,    11.458,    11.224,     3.81 ]
# 平均和牌时还剩几张牌： [22.857,    21.36 ,    30.167,    25.435]
# 流局率：     28.244
# 四家无听流局率：  1.5267175572519085
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 30.0, -20.0, 0.0]
# ==============================Game 132=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [70.0, -20.0, -20.0, -20.0]
# ==============================Game 133=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-36.0, 128.0, -36.0, -36.0]
# ==============================Game 134=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-52.0, 0.0, 0.0, 52.0]
# ==============================Game 135=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [90.0, -80.0, 0.0, 0.0]
# ==============================Game 136=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 137=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -40.0, -20.0, 90.0]
# ==============================Game 138=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -3.0, -5.0, -3.0]
# ==============================Game 139=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -20.0, 80.0]
# ==============================Game 140=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [58.0, -58.0, 0.0, 0.0]
# ==============================Game 141=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [134.75,    -527.66,    -402.13,    447.52]
# 结果M.S.E.   [287.32,    281.70,    283.25,    348.34]
# 自摸率：     [46.88,    48.15,    77.78,    88.46]
# 放铳率：     [ 2.13,    12.06,     9.93,     2.84]
# 和了率：     [22.695,    19.149,    12.766,    18.44 ]
# 副露率：     [31.206,    34.752,    23.404,    39.007]
# 立直率：     [26.95 ,    27.66 ,    24.113,    19.858]
# 立直成功率：  [28.947,    30.769,    32.353,    46.429]
# 暗和率：     [65.625,    55.556,    38.889,    50.   ]
# 平均打点：   [4538.,    4178.,    6106.,    6850.]
# 没立铳率：   [ 1.942,    12.745,    11.215,     3.54 ]
# 平均和牌时还剩几张牌： [22.594,    21.444,    30.167,    23.269]
# 流局率：     26.95
# 四家无听流局率：  1.4184397163120568
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, 25.0, -5.0, -5.0]
# ==============================Game 142=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -40.0, 90.0]
# ==============================Game 143=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [40.0, -20.0, 0.0, 0.0]
# ==============================Game 144=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, -30.0, 10.0, 10.0]
# ==============================Game 145=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, -30.0, 10.0, 10.0]
# ==============================Game 146=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -39.0, 89.0]
# ==============================Game 147=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 30.0, -20.0]
# ==============================Game 148=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-39.0, -20.0, 89.0, -20.0]
# ==============================Game 149=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, 35.0, -5.0, -5.0]
# ==============================Game 150=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [70.0, -10.0, -20.0, -10.0]
# ==============================Game 151=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [126.49,    -558.94,    -382.12,    483.44]
# 结果M.S.E.   [274.82,    267.23,    273.53,    334.31]
# 自摸率：     [47.06,    51.72,    75.00,    89.29]
# 放铳率：     [ 1.99,    11.92,     9.27,     3.31]
# 和了率：     [22.517,    19.205,    13.245,    18.543]
# 副露率：     [30.464,    34.437,    23.841,    39.073]
# 立直率：     [27.815,    26.49 ,    25.166,    21.192]
# 立直成功率：  [28.571,    30.   ,    34.211,    46.875]
# 暗和率：     [64.706,    58.621,    35.   ,    46.429]
# 平均打点：   [4565.,    4097.,    5990.,    6929.]
# 没立铳率：   [ 1.835,    11.712,    10.619,     4.202]
# 平均和牌时还剩几张牌： [22.324,    20.862,    29.35 ,    22.25 ]
# 流局率：     26.49
# 四家无听流局率：  1.3245033112582782
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 152=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, 20.0, -5.0, -5.0]
# ==============================Game 153=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [110.0, -80.0, 0.0, 0.0]
# ==============================Game 154=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-7.0, -7.0, -13.0, 37.0]
# ==============================Game 155=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-60.0, -60.0, -60.0, 190.0]
# ==============================Game 156=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-40.0, -20.0, -20.0, 80.0]
# ==============================Game 157=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [40.0, -20.0, 0.0, 0.0]
# ==============================Game 158=============================
# ~~~~~~~~~~~~Result:  ResultType.IntervalRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 159=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 160=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 161=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [123.60,    -649.69,    -440.99,    637.89]
# 结果M.S.E.   [270.15,    259.40,    259.30,    335.74]
# 自摸率：     [44.44,    53.33,    75.00,    90.32]
# 放铳率：     [ 1.86,    12.42,     8.70,     3.11]
# 和了率：     [22.36 ,    18.634,    12.422,    19.255]
# 副露率：     [30.435,    34.161,    24.224,    38.509]
# 立直率：     [27.95 ,    26.708,    23.602,    22.36 ]
# 立直成功率：  [31.111,    27.907,    34.211,    47.222]
# 暗和率：     [61.111,    60.   ,    35.   ,    45.161]
# 平均打点：   [4672.,    4027.,    5990.,    7184.]
# 没立铳率：   [ 1.724,    11.017,     9.756,     4.   ]
# 平均和牌时还剩几张牌： [21.917,    20.4  ,    29.35 ,    23.226]
# 流局率：     27.329
# 四家无听流局率：  1.2422360248447204
# ~~~~~~~~~~~~Result:  ResultType.IntervalRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 162=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -39.0, 99.0]
# ==============================Game 163=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 36.0, -26.0]
# ==============================Game 164=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 165=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-7.0, -13.0, -7.0, 47.0]
# ==============================Game 166=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -10.0, 40.0, -10.0]
# ==============================Game 167=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-4.0, 25.0, -4.0, -7.0]
# ==============================Game 168=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 20.0, -20.0]
# ==============================Game 169=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-10.0, 0.0, 0.0, 20.0]
# ==============================Game 170=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 20.0, -10.0, 0.0]
# ==============================Game 171=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [69.01,    -616.37,    -417.54,    643.27]
# 结果M.S.E.   [255.34,    245.69,    247.61,    321.81]
# 自摸率：     [44.44,    53.12,    69.57,    88.24]
# 放铳率：     [ 2.34,    11.70,     8.77,     4.09]
# 和了率：     [21.053,    18.713,    13.45 ,    19.883]
# 副露率：     [28.655,    33.918,    25.146,    38.012]
# 立直率：     [28.07 ,    25.731,    24.561,    22.807]
# 立直成功率：  [29.167,    27.273,    35.714,    48.718]
# 暗和率：     [61.111,    62.5  ,    34.783,    44.118]
# 平均打点：   [4672.,    3916.,    5539.,    6979.]
# 没立铳率：   [ 1.626,    10.236,     9.302,     5.303]
# 平均和牌时还剩几张牌： [21.917,    20.969,    28.435,    23.235]
# 流局率：     26.901
# 四家无听流局率：  1.7543859649122806
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [20.0, -20.0, 0.0, 0.0]
# ==============================Game 172=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -10.0, 60.0, -10.0]
# ==============================Game 173=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 174=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, -15.0, 15.0]
# ==============================Game 175=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 90.0, -80.0, 0.0]
# ==============================Game 176=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 77.0, -77.0, 0.0]
# ==============================Game 177=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [130.0, -120.0, 0.0, 0.0]
# ==============================Game 178=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-13.0, 62.0, -26.0, -13.0]
# ==============================Game 179=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, -15.0, 15.0]
# ==============================Game 180=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [15.0, -5.0, -5.0, -5.0]
# ==============================Game 181=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [149.17,    -580.11,    -492.82,    597.79]
# 结果M.S.E.   [250.98,    251.81,    243.31,    304.65]
# 自摸率：     [43.59,    52.94,    70.83,    88.24]
# 放铳率：     [ 2.21,    12.15,     8.84,     3.87]
# 和了率：     [21.547,    18.785,    13.26 ,    18.785]
# 副露率：     [28.729,    34.254,    25.414,    38.122]
# 立直率：     [28.729,    25.967,    23.757,    22.099]
# 立直成功率：  [28.846,    29.787,    37.209,    47.5  ]
# 暗和率：     [61.538,    58.824,    33.333,    44.118]
# 平均打点：   [4710.,    4074.,    5517.,    6979.]
# 没立铳率：   [ 1.55 ,    11.194,     9.42 ,     4.965]
# 平均和牌时还剩几张牌： [21.026,    21.265,    27.375,    23.235]
# 流局率：     27.624
# 四家无听流局率：  1.6574585635359116
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 182=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 59.0, -39.0]
# ==============================Game 183=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 36.0, -26.0]
# ==============================Game 184=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 87.0, -77.0, 0.0]
# ==============================Game 185=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -39.0, -20.0, 89.0]
# ==============================Game 186=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [100.0, -80.0, 0.0, 0.0]
# ==============================Game 187=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, -15.0, 15.0]
# ==============================Game 188=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [200.0, -60.0, -60.0, -60.0]
# ==============================Game 189=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-30.0, 10.0, 10.0, 10.0]
# ==============================Game 190=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -40.0, 90.0]
# ==============================Game 191=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [261.78,    -629.32,    -541.36,    579.06]
# 结果M.S.E.   [262.62,    248.98,    238.72,    298.12]
# 自摸率：     [45.00,    51.43,    65.38,    88.89]
# 放铳率：     [ 2.09,    11.52,     8.90,     4.71]
# 和了率：     [20.942,    18.325,    13.613,    18.848]
# 副露率：     [28.796,    33.508,    25.131,    38.22 ]
# 立直率：     [28.796,    27.225,    23.56 ,    23.037]
# 立直成功率：  [29.091,    28.846,    40.   ,    47.727]
# 暗和率：     [60.   ,    57.143,    30.769,    41.667]
# 平均打点：   [5068.,    4177.,    5381.,    7033.]
# 没立铳率：   [ 1.471,    10.791,     9.589,     6.122]
# 平均和牌时还剩几张牌： [20.775,    21.543,    26.962,    22.833]
# 流局率：     28.272
# 四家无听流局率：  1.5706806282722514
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 40.0, -20.0, 0.0]
# ==============================Game 192=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [120.0, -40.0, -40.0, -40.0]
# ==============================Game 193=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 90.0, -80.0]
# ==============================Game 194=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 195=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 49.0, -39.0, 0.0]
# ==============================Game 196=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [25.0, -5.0, -5.0, -5.0]
# ==============================Game 197=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-3.0, -5.0, -3.0, 11.0]
# ==============================Game 198=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -3.0, -5.0, -3.0]
# ==============================Game 199=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 10.0, -10.0, 0.0]
# ==============================Game 200=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 201=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [319.90,    -580.10,    -555.22,    492.04]
# 结果M.S.E.   [256.72,    239.42,    232.47,    287.68]
# 自摸率：     [48.84,    47.37,    62.96,    89.19]
# 放铳率：     [ 1.99,    10.95,     9.95,     4.98]
# 和了率：     [21.393,    18.905,    13.433,    18.408]
# 副露率：     [28.856,    32.836,    24.876,    40.299]
# 立直率：     [27.861,    27.861,    23.383,    21.891]
# 立直成功率：  [28.571,    30.357,    40.426,    47.727]
# 暗和率：     [62.791,    55.263,    29.63 ,    43.243]
# 平均打点：   [5077.,    4055.,    5478.,    6873.]
# 没立铳率：   [ 1.379,    10.345,    10.39 ,     6.369]
# 平均和牌时还剩几张牌： [21.953,    21.079,    26.741,    23.784]
# 流局率：     27.861
# 四家无听流局率：  1.492537313432836
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [60.0, -20.0, -10.0, -10.0]
# ==============================Game 202=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 203=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [40.0, -5.0, -5.0, -10.0]
# ==============================Game 204=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 205=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 206=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 130.0, -120.0]
# ==============================Game 207=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-36.0, -36.0, -36.0, 128.0]
# ==============================Game 208=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 59.0, -39.0]
# ==============================Game 209=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 210=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -10.0, 40.0, -10.0]
# ==============================Game 211=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [316.11,    -586.26,    -487.20,    416.11]
# 结果M.S.E.   [247.36,    229.62,    232.39,    286.88]
# 自摸率：     [51.11,    47.37,    60.00,    89.47]
# 放铳率：     [ 1.90,    10.43,     9.48,     5.69]
# 和了率：     [21.327,    18.009,    14.218,    18.009]
# 副露率：     [27.962,    32.227,    24.171,    38.863]
# 立直率：     [29.384,    29.384,    23.697,    21.801]
# 立直成功率：  [27.419,    27.419,    42.   ,    47.826]
# 暗和率：     [62.222,    55.263,    30.   ,    42.105]
# 平均打点：   [5051.,    4055.,    5627.,    7003.]
# 没立铳率：   [ 1.342,    10.067,     9.938,     7.273]
# 平均和牌时还剩几张牌： [21.533,    21.079,    26.5  ,    23.5  ]
# 流局率：     28.436
# 四家无听流局率：  1.4218009478672986
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [90.0, -20.0, -20.0, -40.0]
# ==============================Game 212=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-60.0, -30.0, 140.0, -30.0]
# ==============================Game 213=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [30.0, -20.0, 0.0, 0.0]
# ==============================Game 214=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 215=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-30.0, -30.0, 130.0, -60.0]
# ==============================Game 216=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -5.0, -5.0, 20.0]
# ==============================Game 217=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -10.0, 30.0, -5.0]
# ==============================Game 218=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, 30.0, -10.0, -5.0]
# ==============================Game 219=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, 80.0, -40.0]
# ==============================Game 220=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -3.0, 31.0, -3.0]
# ==============================Game 221=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [290.50,    -617.65,    -313.12,    309.95]
# 结果M.S.E.   [242.42,    220.68,    240.70,    278.13]
# 自摸率：     [51.06,    48.72,    65.71,    89.74]
# 放铳率：     [ 1.81,    10.41,     9.05,     5.43]
# 和了率：     [21.267,    17.647,    15.837,    17.647]
# 副露率：     [27.149,    33.032,    25.339,    37.557]
# 立直率：     [29.864,    28.507,    23.982,    21.719]
# 立直成功率：  [27.273,    26.984,    45.283,    45.833]
# 暗和率：     [61.702,    56.41 ,    31.429,    43.59 ]
# 平均打点：   [5070.,    4028.,    5911.,    6874.]
# 没立铳率：   [ 1.29 ,    10.127,     9.524,     6.936]
# 平均和牌时还剩几张牌： [21.128,    21.154,    26.4  ,    23.897]
# 流局率：     27.602
# 四家无听流局率：  1.3574660633484164
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -20.0, 40.0, -10.0]
# ==============================Game 222=============================
# ~~~~~~~~~~~~Result:  ResultType.IntervalRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 223=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, 80.0, -40.0]
# ==============================Game 224=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, 30.0, -5.0, -5.0]
# ==============================Game 225=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 30.0, -20.0]
# ==============================Game 226=============================
# ~~~~~~~~~~~~Result:  ResultType.RyuuKyokuMangan [-20.0, 80.0, -40.0, -20.0]
# ==============================Game 227=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 10.0, -10.0]
# ==============================Game 228=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 39.0, -39.0]
# ==============================Game 229=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-3.0, -5.0, -3.0, 21.0]
# ==============================Game 230=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-13.0, -13.0, -26.0, 52.0]
# ==============================Game 231=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [236.36,    -572.73,    -249.78,    265.80]
# 结果M.S.E.   [232.96,    215.23,    235.53,    268.81]
# 自摸率：     [51.06,    50.00,    62.50,    90.24]
# 放铳率：     [ 1.73,     9.96,     8.66,     6.49]
# 和了率：     [20.346,    17.316,    17.316,    17.749]
# 副露率：     [27.273,    32.9  ,    26.407,    38.095]
# 立直率：     [29.437,    27.706,    23.377,    20.779]
# 立直成功率：  [26.471,    26.562,    46.296,    45.833]
# 暗和率：     [61.702,    57.5  ,    37.5  ,    46.341]
# 平均打点：   [5070.,    4002.,    5645.,    6717.]
# 没立铳率：   [1.227,    9.581,    9.04 ,    8.197]
# 平均和牌时还剩几张牌： [21.128,    21.45 ,    27.2  ,    23.39 ]
# 流局率：     27.273
# 四家无听流局率：  1.2987012987012987
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, 100.0, -20.0, -40.0]
# ==============================Game 232=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-40.0, -20.0, -20.0, 100.0]
# ==============================Game 233=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 234=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 235=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-30.0, 130.0, -30.0, -60.0]
# ==============================Game 236=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 90.0, -80.0]
# ==============================Game 237=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 30.0, -20.0, 0.0]
# ==============================Game 238=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 130.0, -120.0]
# ==============================Game 239=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, 40.0, -5.0, -10.0]
# ==============================Game 240=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [29.0, -29.0, 0.0, 0.0]
# ==============================Game 241=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [209.54,    -455.19,    -218.67,    148.96]
# 结果M.S.E.   [224.99,    217.93,    235.00,    269.39]
# 自摸率：     [50.00,    52.27,    59.52,    90.48]
# 放铳率：     [ 1.66,     9.96,     8.71,     7.05]
# 和了率：     [19.917,    18.257,    17.427,    17.427]
# 副露率：     [27.801,    32.365,    26.141,    36.929]
# 立直率：     [29.046,    27.801,    24.481,    20.747]
# 立直成功率：  [25.714,    29.851,    45.763,    46.   ]
# 暗和率：     [62.5  ,    54.545,    35.714,    45.238]
# 平均打点：   [5025.,    4252.,    5852.,    6771.]
# 没立铳率：   [1.17 ,    9.77 ,    9.341,    8.901]
# 平均和牌时还剩几张牌： [21.812,    22.205,    27.   ,    23.071]
# 流局率：     26.971
# 四家无听流局率：  1.2448132780082988
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [89.0, -39.0, -20.0, -20.0]
# ==============================Game 242=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -10.0, -20.0, 50.0]
# ==============================Game 243=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-36.0, -36.0, -36.0, 118.0]
# ==============================Game 244=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 20.0, -10.0, 0.0]
# ==============================Game 245=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, -15.0, 15.0]
# ==============================Game 246=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [90.0, -80.0, 0.0, 0.0]
# ==============================Game 247=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 30.0, -20.0, 0.0]
# ==============================Game 248=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [108.0, -36.0, -36.0, -36.0]
# ==============================Game 249=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, 10.0, -30.0, 10.0]
# ==============================Game 250=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 68.0, -58.0]
# ==============================Game 251=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [291.24,    -507.17,    -269.32,    166.53]
# 结果M.S.E.   [224.90,    213.15,    228.80,    264.89]
# 自摸率：     [50.98,    50.00,    58.14,    90.91]
# 放铳率：     [ 1.59,     9.96,     9.16,     7.17]
# 和了率：     [20.319,    18.327,    17.131,    17.53 ]
# 副露率：     [28.685,    32.669,    25.896,    37.052]
# 立直率：     [29.482,    27.49 ,    24.701,    20.717]
# 立直成功率：  [27.027,    30.435,    45.161,    46.154]
# 暗和率：     [60.784,    54.348,    34.884,    45.455]
# 平均打点：   [5253.,    4154.,    5851.,    6823.]
# 没立铳率：   [1.13 ,    9.89 ,    9.524,    9.045]
# 平均和牌时还剩几张牌： [22.98 ,    22.435,    27.047,    23.182]
# 流局率：     26.693
# 四家无听流局率：  1.1952191235059761
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 252=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, -30.0, 10.0, 10.0]
# ==============================Game 253=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 49.0, -39.0]
# ==============================Game 254=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-13.0, 0.0, 0.0, 43.0]
# ==============================Game 255=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, 80.0, -20.0, -40.0]
# ==============================Game 256=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -10.0, 70.0, -10.0]
# ==============================Game 257=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 90.0, -80.0]
# ==============================Game 258=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [40.0, -20.0, 0.0, 0.0]
# ==============================Game 259=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-15.0, 0.0, 0.0, 15.0]
# ==============================Game 260=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [49.0, -29.0, 0.0, 0.0]
# ==============================Game 261=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [288.12,    -502.68,    -205.75,    109.96]
# 结果M.S.E.   [218.03,    208.18,    224.93,    258.01]
# 自摸率：     [49.06,    51.06,    56.52,    89.13]
# 放铳率：     [ 1.92,    10.34,     8.81,     7.66]
# 和了率：     [20.307,    18.008,    17.625,    17.625]
# 副露率：     [29.119,    32.184,    25.67 ,    37.548]
# 立直率：     [29.885,    27.203,    25.67 ,    20.69 ]
# 立直成功率：  [28.205,    29.577,    44.776,    46.296]
# 暗和率：     [58.491,    55.319,    34.783,    45.652]
# 平均打点：   [5185.,    4236.,    5880.,    6630.]
# 没立铳率：   [ 1.639,    10.526,     9.278,     9.662]
# 平均和牌时还剩几张牌： [22.377,    22.894,    27.326,    22.935]
# 流局率：     26.437
# 四家无听流局率：  1.1494252873563218
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 262=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-30.0, -30.0, -60.0, 130.0]
# ==============================Game 263=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -5.0, 40.0, -10.0]
# ==============================Game 264=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 72.0, -52.0, 0.0]
# ==============================Game 265=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -10.0, 30.0, -5.0]
# ==============================Game 266=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 40.0, -20.0]
# ==============================Game 267=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, 10.0, 10.0, -30.0]
# ==============================Game 268=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -3.0, -3.0, 11.0]
# ==============================Game 269=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-120.0, 0.0, 0.0, 130.0]
# ==============================Game 270=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [13.0, -13.0, 0.0, 0.0]
# ==============================Game 271=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [217.71,    -491.14,    -214.76,    181.92]
# 结果M.S.E.   [216.10,    202.32,    219.27,    257.57]
# 自摸率：     [48.15,    50.00,    57.14,    87.76]
# 放铳率：     [ 2.21,    10.33,     8.86,     7.75]
# 和了率：     [19.926,    17.712,    18.081,    18.081]
# 副露率：     [29.151,    31.365,    25.461,    37.269]
# 立直率：     [29.151,    27.306,    26.199,    21.033]
# 立直成功率：  [27.848,    29.73 ,    46.479,    45.614]
# 暗和率：     [59.259,    54.167,    32.653,    46.939]
# 平均打点：   [5113.,    4277.,    5684.,    6757.]
# 没立铳率：   [ 1.562,    10.66 ,     9.5  ,     9.346]
# 平均和牌时还剩几张牌： [22.926,    22.896,    27.265,    23.633]
# 流局率：     26.199
# 四家无听流局率：  1.1070110701107012
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 272=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-20.0, 0.0, 0.0, 30.0]
# ==============================Game 273=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -10.0, -5.0, 20.0]
# ==============================Game 274=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 275=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-3.0, 11.0, -3.0, -5.0]
# ==============================Game 276=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 36.0, -26.0, 0.0]
# ==============================Game 277=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 130.0, -120.0, 0.0]
# ==============================Game 278=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -3.0, -5.0, -3.0]
# ==============================Game 279=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -20.0, 80.0]
# ==============================Game 280=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 49.0, -39.0]
# ==============================Game 281=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [186.12,    -422.42,    -267.62,    201.42]
# 结果M.S.E.   [209.17,    200.72,    216.42,    250.43]
# 自摸率：     [49.09,    49.02,    56.00,    86.54]
# 放铳率：     [ 2.49,     9.96,     9.25,     7.83]
# 和了率：     [19.573,    18.149,    17.794,    18.505]
# 副露率：     [28.826,    30.961,    25.623,    37.722]
# 立直率：     [29.181,    27.402,    25.623,    20.641]
# 立直成功率：  [26.829,    31.169,    47.222,    46.552]
# 暗和率：     [60.   ,    52.941,    32.   ,    48.077]
# 平均打点：   [5040.,    4333.,    5648.,    6598.]
# 没立铳率：   [ 1.508,    10.294,    10.048,     9.417]
# 平均和牌时还剩几张牌： [23.309,    23.353,    27.08 ,    24.019]
# 流局率：     25.979
# 四家无听流局率：  1.0676156583629892
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-13.0, 0.0, 0.0, 43.0]
# ==============================Game 282=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [20.0, -20.0, 0.0, 0.0]
# ==============================Game 283=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [90.0, -20.0, -20.0, -40.0]
# ==============================Game 284=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 285=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 286=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-16.0, 74.0, -32.0, -16.0]
# ==============================Game 287=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 30.0, -20.0]
# ==============================Game 288=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, -15.0, 15.0]
# ==============================Game 289=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -20.0, -10.0, 50.0]
# ==============================Game 290=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-36.0, -36.0, 118.0, -36.0]
# ==============================Game 291=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [186.60,    -424.05,    -240.89,    169.07]
# 结果M.S.E.   [204.72,    195.86,    213.15,    243.65]
# 自摸率：     [49.12,    50.00,    55.77,    85.19]
# 放铳率：     [ 2.75,     9.97,     8.93,     7.90]
# 和了率：     [19.588,    17.869,    17.869,    18.557]
# 副露率：     [28.522,    29.897,    25.773,    37.457]
# 立直率：     [29.21 ,    27.835,    25.43 ,    21.306]
# 立直成功率：  [27.059,    30.864,    47.297,    46.774]
# 暗和率：     [59.649,    51.923,    32.692,    46.296]
# 平均打点：   [5039.,    4373.,    5696.,    6489.]
# 没立铳率：   [ 1.456,    10.476,     9.677,     9.17 ]
# 平均和牌时还剩几张牌： [23.632,    23.558,    27.385,    23.741]
# 流局率：     26.117
# 四家无听流局率：  1.0309278350515463
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [46.0, -26.0, 0.0, 0.0]
# ==============================Game 292=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 293=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [89.0, -39.0, -20.0, -20.0]
# ==============================Game 294=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, 10.0, 10.0, -30.0]
# ==============================Game 295=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 59.0, -39.0, 0.0]
# ==============================Game 296=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-40.0, -20.0, -20.0, 80.0]
# ==============================Game 297=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -5.0, -3.0, -3.0]
# ==============================Game 298=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [62.0, -52.0, 0.0, 0.0]
# ==============================Game 299=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-30.0, -30.0, 130.0, -60.0]
# ==============================Game 300=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 74.0, -64.0, 0.0]
# ==============================Game 301=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [219.60,    -436.21,    -241.53,    145.85]
# 结果M.S.E.   [202.14,    193.17,    212.23,    238.28]
# 自摸率：     [49.18,    48.15,    56.60,    85.19]
# 放铳率：     [ 2.66,    10.30,     9.30,     7.64]
# 和了率：     [20.266,    17.94 ,    17.608,    17.94 ]
# 副露率：     [28.904,    29.568,    26.246,    36.545]
# 立直率：     [30.233,    28.239,    24.917,    20.93 ]
# 立直成功率：  [27.473,    31.765,    46.667,    46.032]
# 暗和率：     [59.016,    50.   ,    33.962,    46.296]
# 平均打点：   [5016.,    4420.,    5834.,    6489.]
# 没立铳率：   [ 1.429,    11.111,    10.177,     8.824]
# 平均和牌时还剩几张牌： [23.984,    23.259,    26.943,    23.741]
# 流局率：     26.246
# 四家无听流局率：  0.9966777408637874
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [130.0, -60.0, -30.0, -30.0]
# ==============================Game 302=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -10.0, 50.0, -10.0]
# ==============================Game 303=============================
# ...
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, 21.0, -3.0, -3.0]
# ==============================Game 2929=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [120.0, -60.0, -30.0, -30.0]
# ==============================Game 2930=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-7.0, 47.0, -13.0, -7.0]
# ==============================Game 2931=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-276.94,    -315.69,    81.20,    102.01]
# 结果M.S.E.   [65.42,    66.14,    73.01,    73.62]
# 自摸率：     [45.85,    47.32,    58.54,    62.48]
# 放铳率：     [ 6.86,     8.97,     8.22,     7.92]
# 和了率：     [16.445,    15.933,    19.174,    17.912]
# 副露率：     [26.134,    25.35 ,    30.194,    29.069]
# 立直率：     [31.286,    32.071,    26.339,    26.783]
# 立直成功率：  [23.882,    25.106,    44.819,    39.49 ]
# 暗和率：     [54.564,    49.465,    38.434,    40.952]
# 平均打点：   [4946.,    5245.,    5919.,    6127.]
# 没立铳率：   [6.902,    8.639,    8.569,    8.621]
# 平均和牌时还剩几张牌： [23.969,    23.411,    23.92 ,    24.41 ]
# 流局率：     30.536
# 四家无听流局率：  1.2623677925622654
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-120.0, 0.0, 0.0, 130.0]
# ==============================Game 2932=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [180.0, -60.0, -60.0, -60.0]
# ==============================Game 2933=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 29.0, -29.0, 0.0]
# ==============================Game 2934=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [21.0, -3.0, -5.0, -3.0]
# ==============================Game 2935=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [100.0, -20.0, -20.0, -40.0]
# ==============================Game 2936=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 2937=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -10.0, -5.0, 30.0]
# ==============================Game 2938=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -10.0, 50.0, -10.0]
# ==============================Game 2939=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-60.0, -60.0, -60.0, 180.0]
# ==============================Game 2940=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, 21.0, -3.0, -3.0]
# ==============================Game 2941=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-273.24,    -318.80,    75.42,    108.26]
# 结果M.S.E.   [65.74,    65.99,    72.85,    73.79]
# 自摸率：     [46.19,    47.33,    58.61,    62.50]
# 放铳率：     [ 6.87,     8.94,     8.23,     7.89]
# 和了率：     [16.491,    15.947,    19.143,    17.953]
# 副露率：     [26.148,    25.366,    30.16 ,    29.038]
# 立直率：     [31.35 ,    31.962,    26.318,    26.76 ]
# 立直成功率：  [23.861,    25.106,    44.832,    39.517]
# 暗和率：     [54.639,    49.68 ,    38.366,    41.098]
# 平均打点：   [4975.,    5233.,    5916.,    6155.]
# 没立铳率：   [6.934,    8.596,    8.583,    8.589]
# 平均和牌时还剩几张牌： [23.996,    23.422,    23.893,    24.46 ]
# 流局率：     30.466
# 四家无听流局率：  1.2580754845290718
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 25.0, -15.0, 0.0]
# ==============================Game 2942=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-20.0, 0.0, 0.0, 40.0]
# ==============================Game 2943=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-5.0, -5.0, 20.0, -10.0]
# ==============================Game 2944=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, 15.0, -15.0]
# ==============================Game 2945=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [30.0, -10.0, -10.0, -10.0]
# ==============================Game 2946=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 58.0, -58.0]
# ==============================Game 2947=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -3.0, -3.0, -5.0]
# ==============================Game 2948=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, 10.0, 10.0, -30.0]
# ==============================Game 2949=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-40.0, 140.0, -40.0, -40.0]
# ==============================Game 2950=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 39.0, -29.0]
# ==============================Game 2951=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-273.97,    -313.59,    76.31,    102.58]
# 结果M.S.E.   [65.55,    65.92,    72.65,    73.61]
# 自摸率：     [46.30,    47.35,    58.48,    62.50]
# 放铳率：     [ 6.85,     8.91,     8.23,     7.93]
# 和了率：     [16.469,    15.961,    19.18 ,    17.892]
# 副露率：     [26.093,    25.313,    30.125,    29.041]
# 立直率：     [31.413,    31.921,    26.364,    26.669]
# 立直成功率：  [23.732,    25.265,    44.73 ,    39.517]
# 暗和率：     [54.733,    49.469,    38.516,    41.098]
# 平均打点：   [4967.,    5242.,    5903.,    6155.]
# 没立铳率：   [6.917,    8.561,    8.606,    8.641]
# 平均和牌时还剩几张牌： [24.014,    23.435,    23.936,    24.46 ]
# 流局率：     30.498
# 四家无听流局率：  1.253812267028126
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, -15.0, 15.0]
# ==============================Game 2952=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 97.0, -77.0, 0.0]
# ==============================Game 2953=============================
# ~~~~~~~~~~~~Result:  ResultType.IntervalRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 2954=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, 100.0, -40.0, -20.0]
# ==============================Game 2955=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, 50.0, -10.0, -20.0]
# ==============================Game 2956=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -5.0, 20.0, -5.0]
# ==============================Game 2957=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [10.0, -10.0, 0.0, 0.0]
# ==============================Game 2958=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, -30.0, 10.0, 10.0]
# ==============================Game 2959=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [20.0, -5.0, -5.0, -10.0]
# ==============================Game 2960=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -5.0, 30.0, -5.0]
# ==============================Game 2961=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-273.22,    -307.57,    72.10,    100.71]
# 结果M.S.E.   [65.34,    65.87,    72.49,    73.37]
# 自摸率：     [46.31,    47.47,    58.63,    62.50]
# 放铳率：     [ 6.82,     8.92,     8.24,     7.90]
# 和了率：     [16.481,    16.008,    19.183,    17.832]
# 副露率：     [26.174,    25.329,    30.125,    29.044]
# 立直率：     [31.341,    31.915,    26.376,    26.613]
# 立直成功率：  [23.707,    25.503,    44.686,    39.467]
# 暗和率：     [54.918,    49.156,    38.556,    41.098]
# 平均打点：   [4953.,    5254.,    5889.,    6155.]
# 没立铳率：   [6.886,    8.581,    8.578,    8.606]
# 平均和牌时还剩几张牌： [24.08 ,    23.422,    23.972,    24.46 ]
# 流局率：     30.496
# 四家无听流局率：  1.2495778453225261
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -40.0, -20.0, 80.0]
# ==============================Game 2962=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 2963=============================
# ~~~~~~~~~~~~Result:  ResultType.IntervalRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 2964=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-30.0, 10.0, 10.0, 10.0]
# ==============================Game 2965=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [46.0, -26.0, 0.0, 0.0]
# ==============================Game 2966=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-60.0, -60.0, 180.0, -60.0]
# ==============================Game 2967=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 30.0, -20.0]
# ==============================Game 2968=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 33.0, -13.0]
# ==============================Game 2969=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 58.0, -58.0, 0.0]
# ==============================Game 2970=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 2971=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-275.97,    -308.65,    77.92,    99.09]
# 结果M.S.E.   [65.18,    65.73,    72.54,    73.22]
# 自摸率：     [46.22,    47.37,    58.49,    62.57]
# 放铳率：     [ 6.80,     8.92,     8.25,     7.94]
# 和了率：     [16.459,    15.988,    19.219,    17.805]
# 副露率：     [26.153,    25.345,    30.226,    29.047]
# 立直率：     [31.336,    31.875,    26.321,    26.59 ]
# 立直成功率：  [23.738,    25.449,    44.757,    39.367]
# 暗和率：     [54.806,    49.263,    38.704,    41.21 ]
# 平均打点：   [4950.,    5256.,    5899.,    6158.]
# 没立铳率：   [6.863,    8.547,    8.588,    8.62 ]
# 平均和牌时还剩几张牌： [24.082,    23.482,    23.988,    24.509]
# 流局率：     30.528
# 四家无听流局率：  1.2790306294177045
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-20.0, -20.0, -20.0, 80.0]
# ==============================Game 2972=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [0.0, 0.0, 0.0, 0.0]
# ==============================Game 2973=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, 40.0, -10.0, -10.0]
# ==============================Game 2974=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-26.0, 0.0, 0.0, 36.0]
# ==============================Game 2975=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [130.0, -30.0, -30.0, -60.0]
# ==============================Game 2976=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 2977=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [40.0, -20.0, 0.0, 0.0]
# ==============================Game 2978=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-36.0, -36.0, 118.0, -36.0]
# ==============================Game 2979=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 20.0, -10.0, 0.0]
# ==============================Game 2980=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-26.0, 0.0, 0.0, 56.0]
# ==============================Game 2981=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-275.48,    -310.00,    78.43,    99.46]
# 结果M.S.E.   [65.13,    65.55,    72.40,    73.08]
# 自摸率：     [46.23,    47.38,    58.57,    62.41]
# 放铳率：     [ 6.84,     8.92,     8.25,     7.92]
# 和了率：     [16.471,    16.001,    19.188,    17.846]
# 副露率：     [26.065,    25.361,    30.258,    29.051]
# 立直率：     [31.399,    31.902,    26.367,    26.602]
# 立直成功率：  [23.825,    25.552,    44.656,    39.47 ]
# 暗和率：     [54.582,    49.057,    38.636,    41.165]
# 平均打点：   [4960.,    5242.,    5908.,    6152.]
# 没立铳率：   [6.846,    8.571,    8.61 ,    8.592]
# 平均和牌时还剩几张牌： [24.071,    23.48 ,    24.014,    24.404]
# 流局率：     30.493
# 四家无听流局率：  1.3082858101308286
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, 15.0, -15.0, -15.0]
# ==============================Game 2982=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-36.0, -36.0, 128.0, -36.0]
# ==============================Game 2983=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, 10.0, -30.0, 10.0]
# ==============================Game 2984=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [39.0, -29.0, 0.0, 0.0]
# ==============================Game 2985=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [21.0, -5.0, -3.0, -3.0]
# ==============================Game 2986=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 2987=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, -30.0, 10.0, 10.0]
# ==============================Game 2988=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-40.0, -20.0, -20.0, 90.0]
# ==============================Game 2989=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-80.0, 0.0, 0.0, 90.0]
# ==============================Game 2990=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 2991=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-278.44,    -313.31,    79.34,    104.18]
# 结果M.S.E.   [65.02,    65.36,    72.28,    72.96]
# 自摸率：     [46.25,    47.38,    58.64,    62.48]
# 放铳率：     [ 6.82,     8.93,     8.22,     7.89]
# 和了率：     [16.483,    15.948,    19.157,    17.82 ]
# 副露率：     [26.078,    25.276,    30.324,    29.154]
# 立直率：     [31.394,    31.929,    26.312,    26.647]
# 立直成功率：  [23.855,    25.445,    44.727,    39.398]
# 暗和率：     [54.564,    49.057,    38.569,    41.088]
# 平均打点：   [4951.,    5242.,    5918.,    6156.]
# 没立铳率：   [6.823,    8.595,    8.575,    8.569]
# 平均和牌时还剩几张牌： [24.073,    23.48 ,    24.031,    24.452]
# 流局率：     30.592
# 四家无听流局率：  1.3039117352056169
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [11.0, -3.0, -3.0, -5.0]
# ==============================Game 2992=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 36.0, -26.0]
# ==============================Game 2993=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 2994=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [87.0, -77.0, 0.0, 0.0]
# ==============================Game 2995=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-116.0, 0.0, 0.0, 126.0]
# ==============================Game 2996=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 20.0, -20.0, 0.0]
# ==============================Game 2997=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [10.0, -30.0, 10.0, 10.0]
# ==============================Game 2998=============================
# ~~~~~~~~~~~~Result:  ResultType.NoTileRyuuKyoku [15.0, -15.0, 15.0, -15.0]
# ==============================Game 2999=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [99.0, -20.0, -20.0, -39.0]
# ==============================Game 3000=============================
# ~~~~~~~~~~~~Result:  ResultType.TsumoAgari [-10.0, -5.0, 20.0, -5.0]
# ==============================Game 3001=============================
# ------------------------- Statistics ----------------------
# 平均结果:    [-275.81,    -316.76,    79.84,    104.53]
# 结果M.S.E.   [65.06,    65.21,    72.06,    72.87]
# 自摸率：     [46.37,    47.28,    58.61,    62.36]
# 放铳率：     [ 6.83,     8.93,     8.23,     7.90]
# 和了率：     [16.528,    15.928,    19.16 ,    17.794]
# 副露率：     [26.091,    25.258,    30.39 ,    29.224]
# 立直率：     [31.39 ,    31.889,    26.325,    26.591]
# 立直成功率：  [23.885,    25.392,    44.684,    39.348]
# 暗和率：     [54.637,    49.163,    38.609,    41.199]
# 平均打点：   [4958.,    5235.,    5906.,    6168.]
# 没立铳率：   [6.848,    8.611,    8.593,    8.579]
# 平均和牌时还剩几张牌： [24.04 ,    23.494,    24.057,    24.453]
# 流局率：     30.59
# 四家无听流局率：  1.299566811062979
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [-120.0, 0.0, 0.0, 140.0]
# ==============================Game 3002=============================
# ~~~~~~~~~~~~Result:  ResultType.RonAgari [0.0, 0.0, 25.0, -15.0]
# ==============================Game 3003=============================

# %%
env_test.t.get_phase()

# %%
mp.ResultType.TsumoAgari

# %%
total_results_array = np.array(total_results)
sampled_games = np.zeros([10000, 8, 4])
for i in range(10000):
    sampled_games[i] = total_results_array[np.random.choice(len(total_results_array), 8)]
sampled_match_results = sampled_games.sum(-2)

win_rate = ((sampled_games[:, :, 0] + sampled_games[:, :, 1]).sum(1) > (sampled_games[:, :, 2] + sampled_games[:, :, 3]).sum(1)).mean(0) 
print(win_rate)

# %%
for pid in range(4):
    print(np.mean(np.argmax(sampled_match_results, axis=-1) == pid) * 100, np.std(np.argmax(sampled_match_results, axis=-1) == pid) / 10000 ** 0.5 * 100)

# %%
np.array(total_results).std(axis=0) * 100 / np.sqrt(game)

# %%
to_unicode_tails(env_test.hand_tiles[3])

# %%
plt.pcolor(env_test.get_obs(3)[:6, :])
plt.show()

# %%
env_test.can_riichi_tiles_id

# %%
for act in env_test.t.get_self_actions():
    print(act.action)
    print(int(act.correspond_tiles[0].tile))

# %%
env_test.riichi_tile_id

# %%
int(env_test.t.get_selected_action_tile().tile)

# %%
env_test.t.get_response_actions()[0].action

# %%
env_test.t.players[curr_pid].hand.__len__()

# %%
env_test.Phases[env_test.t.get_phase()]

# %%
env_test.hand_tiles[curr_pid]

# %%
env_test.can_riichi

# %%
env_test.t.get_self_actions()[0].action

# %%
a = set([1,2,3,4,4])

# %%
list(a)

# %%
mp.Action.Kakan
