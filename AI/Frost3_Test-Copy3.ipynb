# %%
from wrapper import *
import MahjongPy as mp
import os
import time
import logging
import warnings

import numpy as np
import scipy.io as sio
import torch
import matplotlib.pyplot as plt

import mahjong
from mahjong.shanten import Shanten

from models import VLOG

# %%
player_i_hand_start_ind = [0, 63, 69, 75]  # later 3 in oracle_obs
player_i_side_start_ind = [6, 12, 18, 24]
player_i_river_start_ind = [30, 37, 44, 51]

dora_indicator_ind = 58
dora_ind = 59
game_wind_ind = 60
self_wind_ind = 61
latest_tile_ind = 62

aka_tile_ints = [16, 16 + 36, 16 + 36 + 36]
player_obs_width = 63

CHILEFT = 34
CHIMIDDLE = 35
CHIRIGHT = 36
PON = 37
ANKAN = 38
MINKAN = 39
ADDKAN = 40

RIICHI = 41
RON = 42
TSUMO = 43
PUSH = 44
NOOP = 45

# %%
UNICODE_TILES = """
    🀇 🀈 🀉 🀊 🀋 🀌 🀍 🀎 🀏 
    🀙 🀚 🀛 🀜 🀝 🀞 🀟 🀠 🀡
    🀐 🀑 🀒 🀓 🀔 🀕 🀖 🀗 🀘
    🀀 🀁 🀂 🀃
    🀆 🀅 🀄
""".split()

EXPLAINS = UNICODE_TILES + ["Chi-Left", "Chi-Middle", "Chi-Right", "Pon", "An-Kan",
           "Min-Kan", "Add-Kan", "Riichi", "Ron", "Tsumo", "Push 99", "Pass", "Pass"]

shanten = Shanten()

def to_unicode_tails(tiles, sort=True):
    unicode_tail_string = ""
    if sort:
        tiles = np.sort(np.array(tiles))

    for tile in tiles:
        unicode_tail_string = unicode_tail_string + UNICODE_TILES[int(tile / 4)]

    return unicode_tail_string

# %%
env_test = EnvMahjong3(force_riichi=False, force_win=True, append_aval_action_obs=True)
max_steps = 1000

# %%
# agent_test0 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_0.model")
# agent_test1 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_1.model")
# agent_test2 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_2.model")
# agent_test = torch.load("./vlog_offlinemj_20210724/search_envid_1_beta_0_alpha_1_kldt_-1_cqla_100/data/mahjong_VLOG_DDQN_0.model")


if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"


# agent_test0 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test1 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))
# agent_test2 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test3 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))

# agent_test0 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test1 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))
# agent_test2 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_0_alpha_1_kldt_-1_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_2.model", map_location=torch.device(device))
# agent_test3 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_0_alpha_1_kldt_-1_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_3.model", map_location=torch.device(device))


agent_test0 = torch.load("./vlog_offlinemj_bc_20210807/search_envid_1_beta_0_alpha_1_kldt_10_bnt_0_dpo_0.25_eqn_1_cqla_0/data/mahjong_VLOG_BC_2.model", map_location=torch.device(device))
agent_test1 = torch.load("./vlog_offlinemj_bc_20210807/search_envid_1_beta_0_alpha_1_kldt_10_bnt_0_dpo_0.25_eqn_1_cqla_0/data/mahjong_VLOG_BC_3.model", map_location=torch.device(device))
agent_test2 = torch.load("./vlog_offlinemj_bc_20210807/search_envid_1_beta_0_alpha_1_kldt_10_bnt_0_dpo_0.25_eqn_1_cqla_0/data/mahjong_VLOG_BC_2.model", map_location=torch.device(device))
agent_test3 = torch.load("./vlog_offlinemj_bc_20210807/search_envid_1_beta_0_alpha_1_kldt_10_bnt_0_dpo_0.25_eqn_1_cqla_0/data/mahjong_VLOG_BC_3.model", map_location=torch.device(device))

# %%
agents_test = [agent_test0, agent_test1, agent_test2, agent_test3]

for agent in agents_test:
    agent.device = device

# %%
full_obs = False

EpiTestRet = 0
steps_taken = 0

tsumo_times = 0
liuju_times = 0
noten_times = 0
houjyu_times = 0
riichi_times = 0

riichi_agari_times = 0
yami_agari_times = 0

not_riichi_houjyu_times = 0

fulu_times = 0
agari_turns = []
agari_times = 0

agari_scores = []
total_results = []

game = 0

# %%
while game < 200000:
    print("==============================Game {}=============================".format(game))
    # reset each episode
    if game % 10 == 1:
        try:
            print("------------------------- Statistics ----------------------")
            print("平均结果:", (np.mean(np.array(total_results), axis=0)))
            print("结果M.S.E.", np.array(total_results).std(axis=0) / np.sqrt(game))
            print("自摸率： %f " % (tsumo_times * 100 / agari_times))
            print("放铳率： %f " % (houjyu_times * 100 / game / 4))
            print("和了率： %f " % (agari_times * 100 / game / 4))
            print("副露率： %f " % (fulu_times * 100 / game / 4))
            print("立直率： %f " % (riichi_times * 100 / game / 4))
            print("立直成功率： %f " % (riichi_agari_times * 100 / riichi_times))
            print("暗和率： %f " % (yami_agari_times  * 100/ agari_times))
            print("流局率： %f" % ((game - agari_times) * 100 / game))
            print("平均和牌时还剩几张牌： %f " % (np.sum(agari_turns) / agari_times))
            print("没立直时的放铳率： %f " % (not_riichi_houjyu_times * 100 / game / 4))
            print("四家无听流局率： %f" % (noten_times * 100 / game))
            print("平均打点：%d " % (np.mean(agari_scores)))
        except:
            pass
    try:
        sp = env_test.reset(game % 4, 'east')
        result_array = np.zeros([4])
        done = False
        has_riichi = [False] * 4

        for tt in range(max_steps):

            # if curr_pid != 0:
            #     a = valid_actions[np.random.randint(len(valid_actions))]

            valid_actions = env_test.get_valid_actions(nhot=False)

            if len(valid_actions) == 1:
                env_test.t.make_selection(0)

            else:
                curr_pid = env_test.get_curr_player_id()

                action_mask = env_test.get_valid_actions(nhot=True)

                if not full_obs:
                    a = agents_test[curr_pid].select(env_test.get_obs(curr_pid), action_mask, greedy=True)
                else:
                    a = agents_test[curr_pid].select(env_test.get_full_obs(curr_pid), action_mask, greedy=True)
                
                if a == RIICHI:
                    riichi_times += 1
                    has_riichi[curr_pid] = True

#                 if a == TSUMO:
#                     print(env_test.get_full_obs(0)[player_i_river_start_ind[curr_pid]:player_i_river_start_ind[curr_pid] + 7,  int(env_test.latest_tile / 4)])
#                     plt.pcolor(env_test.get_obs(curr_pid))
#                     plt.show()

#                 if curr_pid == 0 and len(valid_actions) > 1:
#                     print("-------------- Step {}, player {} ----------------".format(tt, curr_pid))
#                     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
#                     side_tiles_0 = [st[0] for st in env_test.side_tiles[curr_pid]]
#                     print("手牌: ", to_unicode_tails(env_test.hand_tiles[curr_pid]),
#                           "； 副露：", to_unicode_tails(side_tiles_0))
#                     if a < 34:
#                         agent_selection_str = UNICODE_TILES[a]
#                     else:
#                         agent_selection_str = EXPLAINS[a]
                
#                     print("Agent选择打: ", agent_selection_str)

                sp, r, done, _ = env_test.step(curr_pid, a)
                if r < 0 and not done:
                    result_array[curr_pid] += r * 100

            steps_taken += 1

            if done or env_test.t.get_phase() == 16:
                payoffs = env_test.get_payoffs()
                # EpiTestRet += payoffs[0]
                result_array += np.array(payoffs) * 100
                print("~~~~~~~~~~~~Result: ", payoffs)
                total_results.append(result_array)
                for uid in range(4):
                    if len(env_test.side_tiles[uid]) >= 3:
                        fulu_times += 1
                
                if env_test.t.get_remain_tile() == 0:
                    liuju_times += 1
                    if np.max(payoffs) == 0:
                        noten_times += 1
                
                if env_test.t.get_remain_tile() > 0 and np.max(payoffs) > 0:  # not 流局
                    
                    agari_turns.append(env_test.t.get_remain_tile())
                    
                    if has_riichi[np.argmax(payoffs)]:
                        riichi_agari_times += 1
                    else:
                        yami_agari_times += 1
                    
                    if np.count_nonzero(result_array < 0) == 3:
                        tsumo_times += 1
                    else:
                        houjyu_times += 1
                        if not has_riichi[np.argmin(payoffs)]:
                            not_riichi_houjyu_times += 1
                        
                    agari_times += 1
                    agari_scores.append(np.max(result_array))
                    
#                     win_pid = np.argmax(result_array)
#                     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
#                     side_tiles_0 = [st[0] for st in env_test.side_tiles[win_pid]]
#                     print("手牌: ", to_unicode_tails(env_test.hand_tiles[win_pid]),
#                           "； 副露：", to_unicode_tails(side_tiles_0))

                # print(env_test.t.game_log.to_string())
#                 if np.max(payoffs) > 0:
#                     plt.pcolor(sp)
#                     plt.show()
#                     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
#                     side_tiles_0 = [st[0] for st in env_test.side_tiles[np.argmax(payoffs)]]
#                     print("手牌: ", to_unicode_tails(env_test.hand_tiles[np.argmax(payoffs)]),
#                       "； 副露：", to_unicode_tails(side_tiles_0))
                break

#             if not done and env_test.t.get_phase() == 0:
#                 shanten_num = np.zeros(4)
#                 for pid in range(4):
#                     shanten_num[pid] = shanten.calculate_shanten(TilesConverter.to_34_array(
#                         env_test.hand_tiles[pid] + [st[0] for st in env_test.side_tiles[pid]]))
#                 print("向听数:", shanten_num)
        game += 1

    except Exception as e:
        print(e)
        if a < 34:
            agent_selection_str = UNICODE_TILES[a]
        else:
            agent_selection_str = EXPLAINS[a]
        print("Agent选择打: ", a)
        time.sleep(0.1)
        continue
# Out:
# ==============================Game 0=============================
# ~~~~~~~~~~~~Result:  [0.0, 20.0, -20.0, 0.0]
# ==============================Game 1=============================
# ------------------------- Statistics ----------------------
# 平均结果: [    0.  2000. -2000.     0.]
# 结果M.S.E. [0. 0. 0. 0.]
# 自摸率： 0.000000
# 放铳率： 25.000000
# 和了率： 25.000000
# 副露率： 50.000000
# 立直率： 0.000000
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 30.0, -10.0]
# ==============================Game 2=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 3=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 4=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 5=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 6=============================
# ~~~~~~~~~~~~Result:  [-3.0, -3.0, -5.0, 11.0]
# ==============================Game 7=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 8=============================
# ~~~~~~~~~~~~Result:  [-5.0, 11.0, -3.0, -3.0]
# ==============================Game 9=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 10.0, -10.0]
# ==============================Game 10=============================
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, 25.0, -5.0]
# ==============================Game 11=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-709.09090909 -200.          836.36363636 -200.        ]
# 结果M.S.E. [177.426295   362.04195912 503.25760738 299.58649188]
# 自摸率： 57.142857
# 放铳率： 6.818182
# 和了率： 15.909091
# 副露率： 34.090909
# 立直率： 13.636364
# 立直成功率： 16.666667
# 暗和率： 85.714286
# 流局率： 36.363636
# 平均和牌时还剩几张牌： 23.714286
# 没立直时的放铳率： 4.545455
# 四家无听流局率： 0.000000
# 平均打点：1814
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 26.0, -26.0]
# ==============================Game 12=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 13=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 14=============================
# ~~~~~~~~~~~~Result:  [49.0, 0.0, -39.0, 0.0]
# ==============================Game 15=============================
# ~~~~~~~~~~~~Result:  [89.0, -20.0, -20.0, -39.0]
# ==============================Game 16=============================
# ~~~~~~~~~~~~Result:  [0.0, 46.0, -26.0, 0.0]
# ==============================Game 17=============================
# ~~~~~~~~~~~~Result:  [-5.0, 15.0, -5.0, -5.0]
# ==============================Game 18=============================
# ~~~~~~~~~~~~Result:  [0.0, 90.0, -80.0, 0.0]
# ==============================Game 19=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 20=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 21=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 190.47619048  400.         -461.9047619  -414.28571429]
# 结果M.S.E. [473.08054771 498.06883295 555.51149809 286.37112707]
# 自摸率： 50.000000
# 放铳率： 8.333333
# 和了率： 16.666667
# 副露率： 28.571429
# 立直率： 16.666667
# 立直成功率： 35.714286
# 暗和率： 64.285714
# 流局率： 33.333333
# 平均和牌时还剩几张牌： 23.000000
# 没立直时的放铳率： 7.142857
# 四家无听流局率： 0.000000
# 平均打点：3085
# ~~~~~~~~~~~~Result:  [-13.0, 49.0, -13.0, -13.0]
# ==============================Game 22=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 23=============================
# ~~~~~~~~~~~~Result:  [20.0, -5.0, -5.0, -10.0]
# ==============================Game 24=============================
# ~~~~~~~~~~~~Result:  [-52.0, 0.0, 0.0, 72.0]
# ==============================Game 25=============================
# ~~~~~~~~~~~~Result:  [39.0, -39.0, 0.0, 0.0]
# ==============================Game 26=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 27=============================
# ~~~~~~~~~~~~Result:  [-60.0, -60.0, -60.0, 190.0]
# ==============================Game 28=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 29=============================
# ~~~~~~~~~~~~Result:  [-20.0, 70.0, -20.0, -20.0]
# ==============================Game 30=============================
# ~~~~~~~~~~~~Result:  [-60.0, -60.0, 180.0, -60.0]
# ==============================Game 31=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-374.19354839  158.06451613 -145.16129032  135.48387097]
# 结果M.S.E. [494.46399872 522.09802871 728.74442947 686.14273288]
# 自摸率： 57.142857
# 放铳率： 7.258065
# 和了率： 16.935484
# 副露率： 29.032258
# 立直率： 16.129032
# 立直成功率： 40.000000
# 暗和率： 61.904762
# 流局率： 32.258065
# 平均和牌时还剩几张牌： 21.619048
# 没立直时的放铳率： 5.645161
# 四家无听流局率： 0.000000
# 平均打点：4866
# ~~~~~~~~~~~~Result:  [89.0, -20.0, -20.0, -39.0]
# ==============================Game 32=============================
# ~~~~~~~~~~~~Result:  [70.0, -20.0, -20.0, -20.0]
# ==============================Game 33=============================
# ~~~~~~~~~~~~Result:  [-20.0, 60.0, -20.0, -20.0]
# ==============================Game 34=============================
# ~~~~~~~~~~~~Result:  [-5.0, 20.0, -10.0, -5.0]
# ==============================Game 35=============================
# ~~~~~~~~~~~~Result:  [-58.0, 0.0, 0.0, 88.0]
# ==============================Game 36=============================
# ~~~~~~~~~~~~Result:  [-77.0, 0.0, 0.0, 87.0]
# ==============================Game 37=============================
# ~~~~~~~~~~~~Result:  [-36.0, 118.0, -36.0, -36.0]
# ==============================Game 38=============================
# ~~~~~~~~~~~~Result:  [-30.0, -30.0, -60.0, 130.0]
# ==============================Game 39=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 40=============================
# ~~~~~~~~~~~~Result:  [0.0, 62.0, -52.0, 0.0]
# ==============================Game 41=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-556.09756098  521.95121951 -604.87804878  468.29268293]
# 结果M.S.E. [522.55548314 524.52649614 591.05921537 677.59626086]
# 自摸率： 60.000000
# 放铳率： 7.317073
# 和了率： 18.292683
# 副露率： 32.317073
# 立直率： 17.682927
# 立直成功率： 48.275862
# 暗和率： 53.333333
# 流局率： 26.829268
# 平均和牌时还剩几张牌： 22.433333
# 没立直时的放铳率： 5.487805
# 四家无听流局率： 0.000000
# 平均打点：5620
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 42=============================
# ~~~~~~~~~~~~Result:  [-10.0, 70.0, -20.0, -10.0]
# ==============================Game 43=============================
# ~~~~~~~~~~~~Result:  [30.0, -20.0, 0.0, 0.0]
# ==============================Game 44=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 45=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 46=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, 60.0, -20.0]
# ==============================Game 47=============================
# ~~~~~~~~~~~~Result:  [10.0, 10.0, -30.0, 10.0]
# ==============================Game 48=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 49=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 50=============================
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, 15.0, -5.0]
# ==============================Game 51=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-564.70588235  400.         -447.05882353  396.07843137]
# 结果M.S.E. [430.22863953 446.05149671 499.54499051 553.83019051]
# 自摸率： 61.764706
# 放铳率： 6.372549
# 和了率： 16.666667
# 副露率： 31.372549
# 立直率： 18.137255
# 立直成功率： 40.540541
# 暗和率： 55.882353
# 流局率： 33.333333
# 平均和牌时还剩几张牌： 21.941176
# 没立直时的放铳率： 4.901961
# 四家无听流局率： 1.960784
# 平均打点：5444
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, -5.0, 25.0]
# ==============================Game 52=============================
# ~~~~~~~~~~~~Result:  [-20.0, 50.0, -10.0, -10.0]
# ==============================Game 53=============================
# ~~~~~~~~~~~~Result:  [-20.0, 0.0, 0.0, 30.0]
# ==============================Game 54=============================
# ~~~~~~~~~~~~Result:  [-26.0, 0.0, 0.0, 36.0]
# ==============================Game 55=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 56=============================
# ~~~~~~~~~~~~Result:  [60.0, -20.0, -20.0, -20.0]
# ==============================Game 57=============================
# ~~~~~~~~~~~~Result:  [11.0, -5.0, -3.0, -3.0]
# ==============================Game 58=============================
# ~~~~~~~~~~~~Result:  [140.0, -120.0, 0.0, 0.0]
# ==============================Game 59=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 60=============================
# ~~~~~~~~~~~~Result:  [-10.0, -5.0, -5.0, 30.0]
# ==============================Game 61=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-259.01639344  129.50819672 -477.04918033  426.2295082 ]
# 结果M.S.E. [443.48051139 430.74121764 418.90550781 471.38432303]
# 自摸率： 61.904762
# 放铳率： 6.557377
# 和了率： 17.213115
# 副露率： 30.327869
# 立直率： 18.032787
# 立直成功率： 43.181818
# 暗和率： 54.761905
# 流局率： 31.147541
# 平均和牌时还剩几张牌： 21.833333
# 没立直时的放铳率： 4.918033
# 四家无听流局率： 1.639344
# 平均打点：5221
# ~~~~~~~~~~~~Result:  [-36.0, 118.0, -36.0, -36.0]
# ==============================Game 62=============================
# ~~~~~~~~~~~~Result:  [-40.0, 170.0, -80.0, -40.0]
# ==============================Game 63=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 64=============================
# ~~~~~~~~~~~~Result:  [-40.0, 90.0, -20.0, -20.0]
# ==============================Game 65=============================
# ~~~~~~~~~~~~Result:  [-13.0, 0.0, 0.0, 23.0]
# ==============================Game 66=============================
# ~~~~~~~~~~~~Result:  [-60.0, -60.0, 180.0, -60.0]
# ==============================Game 67=============================
# ~~~~~~~~~~~~Result:  [-3.0, 11.0, -3.0, -5.0]
# ==============================Game 68=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 69=============================
# ~~~~~~~~~~~~Result:  [-13.0, -26.0, 52.0, -13.0]
# ==============================Game 70=============================
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, 15.0, -5.0]
# ==============================Game 71=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-490.14084507  474.64788732 -257.74647887  104.22535211]
# 结果M.S.E. [401.72784392 482.848941   468.50271142 425.33549366]
# 自摸率： 66.666667
# 放铳率： 5.985915
# 和了率： 17.957746
# 副露率： 29.929577
# 立直率： 17.253521
# 立直成功率： 44.897959
# 暗和率： 56.862745
# 流局率： 28.169014
# 平均和牌时还剩几张牌： 22.176471
# 没立直时的放铳率： 4.577465
# 四家无听流局率： 1.408451
# 平均打点：5592
# ~~~~~~~~~~~~Result:  [0.0, 10.0, -10.0, 0.0]
# ==============================Game 72=============================
# ~~~~~~~~~~~~Result:  [-20.0, -10.0, -10.0, 40.0]
# ==============================Game 73=============================
# ~~~~~~~~~~~~Result:  [-30.0, 10.0, 10.0, 10.0]
# ==============================Game 74=============================
# ~~~~~~~~~~~~Result:  [-13.0, 0.0, 0.0, 23.0]
# ==============================Game 75=============================
# ~~~~~~~~~~~~Result:  [-180.0, 0.0, 0.0, 190.0]
# ==============================Game 76=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 77=============================
# ~~~~~~~~~~~~Result:  [0.0, 68.0, -58.0, 0.0]
# ==============================Game 78=============================
# ~~~~~~~~~~~~Result:  [-5.0, 20.0, -10.0, -5.0]
# ==============================Game 79=============================
# ~~~~~~~~~~~~Result:  [-5.0, 20.0, -5.0, -10.0]
# ==============================Game 80=============================
# ~~~~~~~~~~~~Result:  [200.0, -60.0, -60.0, -60.0]
# ==============================Game 81=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-532.09876543  475.30864198 -414.81481481  298.7654321 ]
# 结果M.S.E. [485.39978027 439.13332383 422.31285978 451.15811896]
# 自摸率： 64.406780
# 放铳率： 6.481481
# 和了率： 18.209877
# 副露率： 30.246914
# 立直率： 17.283951
# 立直成功率： 42.857143
# 暗和率： 59.322034
# 流局率： 27.160494
# 平均和牌时还剩几张牌： 22.457627
# 没立直时的放铳率： 4.938272
# 四家无听流局率： 1.234568
# 平均打点：5767
# ~~~~~~~~~~~~Result:  [-10.0, -20.0, 40.0, -10.0]
# ==============================Game 82=============================
# ~~~~~~~~~~~~Result:  [-20.0, 89.0, -39.0, -20.0]
# ==============================Game 83=============================
# ~~~~~~~~~~~~Result:  [0.0, 13.0, -13.0, 0.0]
# ==============================Game 84=============================
# ~~~~~~~~~~~~Result:  [-5.0, -3.0, -3.0, 11.0]
# ==============================Game 85=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 86=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, 70.0, -20.0]
# ==============================Game 87=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 88=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 89=============================
# ~~~~~~~~~~~~Result:  [-20.0, -40.0, 100.0, -20.0]
# ==============================Game 90=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 91=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-528.57142857  438.46153846 -237.36263736  151.64835165]
# 结果M.S.E. [434.56859396 406.21535507 400.9397497  405.85725648]
# 自摸率： 65.625000
# 放铳率： 6.043956
# 和了率： 17.582418
# 副露率： 29.120879
# 立直率： 17.032967
# 立直成功率： 41.935484
# 暗和率： 59.375000
# 流局率： 29.670330
# 平均和牌时还剩几张牌： 22.765625
# 没立直时的放铳率： 4.670330
# 四家无听流局率： 1.098901
# 平均打点：5634
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 92=============================
# ~~~~~~~~~~~~Result:  [-5.0, 11.0, -3.0, -3.0]
# ==============================Game 93=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 94=============================
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, 35.0, -5.0]
# ==============================Game 95=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 96=============================
# ~~~~~~~~~~~~Result:  [58.0, -58.0, 0.0, 0.0]
# ==============================Game 97=============================
# ~~~~~~~~~~~~Result:  [-10.0, -20.0, -10.0, 60.0]
# ==============================Game 98=============================
# ~~~~~~~~~~~~Result:  [27.0, -7.0, -13.0, -7.0]
# ==============================Game 99=============================
# ~~~~~~~~~~~~Result:  [0.0, 20.0, -10.0, 0.0]
# ==============================Game 100=============================
# ~~~~~~~~~~~~Result:  [-40.0, -20.0, 80.0, -20.0]
# ==============================Game 101=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-456.43564356  311.88118812 -170.2970297   126.73267327]
# 结果M.S.E. [399.48112568 374.40483013 373.05465632 370.27556217]
# 自摸率： 65.714286
# 放铳率： 5.940594
# 和了率： 17.326733
# 副露率： 29.207921
# 立直率： 17.326733
# 立直成功率： 38.571429
# 暗和率： 61.428571
# 流局率： 30.693069
# 平均和牌时还剩几张牌： 21.800000
# 没立直时的放铳率： 4.702970
# 四家无听流局率： 1.980198
# 平均打点：5438
# ~~~~~~~~~~~~Result:  [36.0, -26.0, 0.0, 0.0]
# ==============================Game 102=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 103=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 104=============================
# ~~~~~~~~~~~~Result:  [-20.0, -10.0, 60.0, -10.0]
# ==============================Game 105=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 10.0, -10.0]
# ==============================Game 106=============================
# ~~~~~~~~~~~~Result:  [11.0, -3.0, -5.0, -3.0]
# ==============================Game 107=============================
# ~~~~~~~~~~~~Result:  [-3.0, 11.0, -3.0, -5.0]
# ==============================Game 108=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 109=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 110=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 111=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-434.23423423  227.02702703 -130.63063063  121.62162162]
# 结果M.S.E. [366.42973396 342.74264398 343.79679842 338.66782228]
# 自摸率： 65.333333
# 放铳率： 5.855856
# 和了率： 16.891892
# 副露率： 29.054054
# 立直率： 17.567568
# 立直成功率： 37.179487
# 暗和率： 61.333333
# 流局率： 32.432432
# 平均和牌时还剩几张牌： 21.533333
# 没立直时的放铳率： 4.729730
# 四家无听流局率： 1.801802
# 平均打点：5220
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 40.0]
# ==============================Game 112=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 113=============================
# ~~~~~~~~~~~~Result:  [-5.0, -10.0, -5.0, 20.0]
# ==============================Game 114=============================
# ~~~~~~~~~~~~Result:  [-20.0, 90.0, -40.0, -20.0]
# ==============================Game 115=============================
# ~~~~~~~~~~~~Result:  [-20.0, 0.0, 0.0, 30.0]
# ==============================Game 116=============================
# ~~~~~~~~~~~~Result:  [68.0, -48.0, 0.0, 0.0]
# ==============================Game 117=============================
# ~~~~~~~~~~~~Result:  [42.0, -32.0, 0.0, 0.0]
# ==============================Game 118=============================
# ~~~~~~~~~~~~Result:  [72.0, -52.0, 0.0, 0.0]
# ==============================Game 119=============================
# ~~~~~~~~~~~~Result:  [27.0, -7.0, -7.0, -13.0]
# ==============================Game 120=============================
# ~~~~~~~~~~~~Result:  [-39.0, -20.0, 99.0, -20.0]
# ==============================Game 121=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-340.49586777   97.52066116  -93.38842975  113.2231405 ]
# 结果M.S.E. [348.44013838 332.3721235  325.82687452 313.85366257]
# 自摸率： 64.285714
# 放铳率： 6.198347
# 和了率： 17.355372
# 副露率： 28.719008
# 立直率： 18.801653
# 立直成功率： 39.560440
# 暗和率： 57.142857
# 流局率： 30.578512
# 平均和牌时还剩几张牌： 21.654762
# 没立直时的放铳率： 4.545455
# 四家无听流局率： 1.652893
# 平均打点：5158
# ~~~~~~~~~~~~Result:  [-20.0, 0.0, 0.0, 30.0]
# ==============================Game 122=============================
# ~~~~~~~~~~~~Result:  [-40.0, -40.0, 120.0, -40.0]
# ==============================Game 123=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 124=============================
# ~~~~~~~~~~~~Result:  [10.0, -30.0, 10.0, 10.0]
# ==============================Game 125=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 126=============================
# ~~~~~~~~~~~~Result:  [-3.0, -3.0, -5.0, 11.0]
# ==============================Game 127=============================
# ~~~~~~~~~~~~Result:  [10.0, -30.0, 10.0, 10.0]
# ==============================Game 128=============================
# ~~~~~~~~~~~~Result:  [116.0, -116.0, 0.0, 0.0]
# ==============================Game 129=============================
# ~~~~~~~~~~~~Result:  [-5.0, -10.0, 40.0, -5.0]
# ==============================Game 130=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 40.0, -10.0]
# ==============================Game 131=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-289.3129771   -96.18320611   58.77862595   90.07633588]
# 结果M.S.E. [336.2060366  323.07739666 317.17877885 293.41163087]
# 自摸率： 65.168539
# 放铳率： 5.916031
# 和了率： 16.984733
# 副露率： 28.816794
# 立直率： 18.893130
# 立直成功率： 37.373737
# 暗和率： 58.426966
# 流局率： 32.061069
# 平均和牌时还剩几张牌： 22.112360
# 没立直时的放铳率： 4.389313
# 四家无听流局率： 2.290076
# 平均打点：5224
# ~~~~~~~~~~~~Result:  [-116.0, 0.0, 0.0, 136.0]
# ==============================Game 132=============================
# ~~~~~~~~~~~~Result:  [-13.0, -7.0, 37.0, -7.0]
# ==============================Game 133=============================
# ~~~~~~~~~~~~Result:  [-20.0, -39.0, 89.0, -20.0]
# ==============================Game 134=============================
# ~~~~~~~~~~~~Result:  [80.0, -20.0, -40.0, -20.0]
# ==============================Game 135=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 136=============================
# ~~~~~~~~~~~~Result:  [0.0, 10.0, -10.0, 0.0]
# ==============================Game 137=============================
# ~~~~~~~~~~~~Result:  [26.0, -16.0, 0.0, 0.0]
# ==============================Game 138=============================
# ~~~~~~~~~~~~Result:  [100.0, -20.0, -40.0, -20.0]
# ==============================Game 139=============================
# ~~~~~~~~~~~~Result:  [-58.0, 0.0, 0.0, 68.0]
# ==============================Game 140=============================
# ~~~~~~~~~~~~Result:  [-20.0, -10.0, -10.0, 40.0]
# ==============================Game 141=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-301.41843972 -186.5248227    55.31914894  198.58156028]
# 结果M.S.E. [337.69887022 302.56888479 304.12291178 293.41821106]
# 自摸率： 64.285714
# 放铳率： 6.205674
# 和了率： 17.375887
# 副露率： 29.432624
# 立直率： 19.326241
# 立直成功率： 37.614679
# 暗和率： 58.163265
# 流局率： 30.496454
# 平均和牌时还剩几张牌： 22.275510
# 没立直时的放铳率： 4.787234
# 四家无听流局率： 2.127660
# 平均打点：5302
# ~~~~~~~~~~~~Result:  [21.0, -5.0, -3.0, -3.0]
# ==============================Game 142=============================
# ~~~~~~~~~~~~Result:  [-5.0, 30.0, -10.0, -5.0]
# ==============================Game 143=============================
# ~~~~~~~~~~~~Result:  [16.0, -16.0, 0.0, 0.0]
# ==============================Game 144=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 145=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 146=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 147=============================
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, 20.0, -10.0]
# ==============================Game 148=============================
# ~~~~~~~~~~~~Result:  [-40.0, -20.0, -20.0, 100.0]
# ==============================Game 149=============================
# ~~~~~~~~~~~~Result:  [0.0, 58.0, -48.0, 0.0]
# ==============================Game 150=============================
# ~~~~~~~~~~~~Result:  [-26.0, -26.0, 108.0, -26.0]
# ==============================Game 151=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-294.0397351  -209.93377483   69.53642384  202.64900662]
# 结果M.S.E. [317.58572369 286.75382739 293.87710045 281.93562261]
# 自摸率： 64.761905
# 放铳率： 6.125828
# 和了率： 17.384106
# 副露率： 29.139073
# 立直率： 19.701987
# 立直成功率： 37.815126
# 暗和率： 57.142857
# 流局率： 30.463576
# 平均和牌时还剩几张牌： 22.552381
# 没立直时的放铳率： 4.801325
# 四家无听流局率： 2.649007
# 平均打点：5246
# ~~~~~~~~~~~~Result:  [23.0, -13.0, 0.0, 0.0]
# ==============================Game 152=============================
# ~~~~~~~~~~~~Result:  [-5.0, -3.0, -3.0, 21.0]
# ==============================Game 153=============================
# ~~~~~~~~~~~~Result:  [-60.0, 200.0, -60.0, -60.0]
# ==============================Game 154=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 155=============================
# ~~~~~~~~~~~~Result:  [0.0, 20.0, -20.0, 0.0]
# ==============================Game 156=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 157=============================
# ~~~~~~~~~~~~Result:  [-20.0, -39.0, -20.0, 99.0]
# ==============================Game 158=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, -39.0, 89.0]
# ==============================Game 159=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 160=============================
# ~~~~~~~~~~~~Result:  [-39.0, -20.0, 99.0, -20.0]
# ==============================Game 161=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-344.72049689 -144.09937888   -4.9689441   270.1863354 ]
# 结果M.S.E. [302.39569223 296.3635743  286.78680852 277.6596832 ]
# 自摸率： 65.486726
# 放铳率： 6.055901
# 和了率： 17.546584
# 副露率： 29.347826
# 立直率： 20.031056
# 立直成功率： 38.759690
# 暗和率： 55.752212
# 流局率： 29.813665
# 平均和牌时还剩几张牌： 22.309735
# 没立直时的放铳率： 4.813665
# 四家无听流局率： 2.484472
# 平均打点：5345
# ~~~~~~~~~~~~Result:  [-20.0, 80.0, -20.0, -20.0]
# ==============================Game 162=============================
# ~~~~~~~~~~~~Result:  [10.0, 10.0, 10.0, -30.0]
# ==============================Game 163=============================
# ~~~~~~~~~~~~Result:  [-10.0, 50.0, -10.0, -20.0]
# ==============================Game 164=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 165=============================
# ~~~~~~~~~~~~Result:  [-32.0, 106.0, -32.0, -32.0]
# ==============================Game 166=============================
# ~~~~~~~~~~~~Result:  [80.0, -20.0, -40.0, -20.0]
# ==============================Game 167=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 168=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 169=============================
# ~~~~~~~~~~~~Result:  [-20.0, -39.0, -20.0, 89.0]
# ==============================Game 170=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -20.0, 50.0]
# ==============================Game 171=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-334.50292398  -46.78362573  -84.79532164  220.46783626]
# 结果M.S.E. [289.88902997 290.21204969 272.71034734 269.46429043]
# 自摸率： 67.226891
# 放铳率： 5.701754
# 和了率： 17.397661
# 副露率： 28.947368
# 立直率： 20.614035
# 立直成功率： 39.007092
# 暗和率： 53.781513
# 流局率： 30.409357
# 平均和牌时还剩几张牌： 22.151261
# 没立直时的放铳率： 4.532164
# 四家无听流局率： 2.339181
# 平均打点：5415
# ~~~~~~~~~~~~Result:  [-5.0, 30.0, -5.0, -10.0]
# ==============================Game 172=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 173=============================
# ~~~~~~~~~~~~Result:  [-10.0, 40.0, -10.0, -10.0]
# ==============================Game 174=============================
# ~~~~~~~~~~~~Result:  [-4.0, -4.0, -7.0, 15.0]
# ==============================Game 175=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 176=============================
# ~~~~~~~~~~~~Result:  [-10.0, -5.0, -5.0, 20.0]
# ==============================Game 177=============================
# ~~~~~~~~~~~~Result:  [10.0, -30.0, 10.0, 10.0]
# ==============================Game 178=============================
# ~~~~~~~~~~~~Result:  [90.0, -20.0, -40.0, -20.0]
# ==============================Game 179=============================
# ~~~~~~~~~~~~Result:  [39.0, -39.0, 0.0, 0.0]
# ==============================Game 180=============================
# ~~~~~~~~~~~~Result:  [-80.0, 0.0, 0.0, 90.0]
# ==============================Game 181=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-291.16022099  -62.43093923 -130.93922652  235.91160221]
# 结果M.S.E. [282.4142656  277.0322722  258.78813617 259.4307466 ]
# 自摸率： 67.460317
# 放铳率： 5.662983
# 和了率： 17.403315
# 副露率： 29.558011
# 立直率： 20.441989
# 立直成功率： 39.189189
# 暗和率： 53.968254
# 流局率： 30.386740
# 平均和牌时还剩几张牌： 22.452381
# 没立直时的放铳率： 4.558011
# 四家无听流局率： 2.209945
# 平均打点：5348
# ~~~~~~~~~~~~Result:  [10.0, -30.0, 10.0, 10.0]
# ==============================Game 182=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 183=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 40.0]
# ==============================Game 184=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 185=============================
# ~~~~~~~~~~~~Result:  [-36.0, 128.0, -36.0, -36.0]
# ==============================Game 186=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 187=============================
# ~~~~~~~~~~~~Result:  [-77.0, 0.0, 0.0, 87.0]
# ==============================Game 188=============================
# ~~~~~~~~~~~~Result:  [50.0, -10.0, -10.0, -10.0]
# ==============================Game 189=============================
# ~~~~~~~~~~~~Result:  [-36.0, 118.0, -36.0, -36.0]
# ==============================Game 190=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 191=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-335.60209424   19.89528796 -195.81151832  234.03141361]
# 结果M.S.E. [273.24315431 276.52527226 247.77713837 251.33773808]
# 自摸率： 67.938931
# 放铳率： 5.497382
# 和了率： 17.146597
# 副露率： 29.319372
# 立直率： 21.335079
# 立直成功率： 38.036810
# 暗和率： 52.671756
# 流局率： 31.413613
# 平均和牌时还剩几张牌： 22.625954
# 没立直时的放铳率： 4.450262
# 四家无听流局率： 2.094241
# 平均打点：5436
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 120.0, -120.0]
# ==============================Game 192=============================
# ~~~~~~~~~~~~Result:  [49.0, -39.0, 0.0, 0.0]
# ==============================Game 193=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 194=============================
# ~~~~~~~~~~~~Result:  [89.0, -20.0, -39.0, -20.0]
# ==============================Game 195=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, -20.0, 70.0]
# ==============================Game 196=============================
# ~~~~~~~~~~~~Result:  [130.0, -40.0, -40.0, -40.0]
# ==============================Game 197=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 198=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 199=============================
# ~~~~~~~~~~~~Result:  [-3.0, 11.0, -3.0, -5.0]
# ==============================Game 200=============================
# ~~~~~~~~~~~~Result:  [29.0, -29.0, 0.0, 0.0]
# ==============================Game 201=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-197.51243781  -54.22885572 -167.1641791   150.24875622]
# 结果M.S.E. [271.81799345 265.29026353 245.05723874 249.46180963]
# 自摸率： 67.391304
# 放铳率： 5.597015
# 和了率： 17.164179
# 副露率： 28.855721
# 立直率： 20.895522
# 立直成功率： 39.285714
# 暗和率： 52.173913
# 流局率： 31.343284
# 平均和牌时还剩几张牌： 22.797101
# 没立直时的放铳率： 4.601990
# 四家无听流局率： 1.990050
# 平均打点：5492
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 202=============================
# ~~~~~~~~~~~~Result:  [-3.0, 11.0, -5.0, -3.0]
# ==============================Game 203=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 204=============================
# ~~~~~~~~~~~~Result:  [0.0, 40.0, -20.0, 0.0]
# ==============================Game 205=============================
# ~~~~~~~~~~~~Result:  [0.0, 29.0, -29.0, 0.0]
# ==============================Game 206=============================
# ~~~~~~~~~~~~Result:  [0.0, 46.0, -26.0, 0.0]
# ==============================Game 207=============================
# ~~~~~~~~~~~~Result:  [10.0, -10.0, 0.0, 0.0]
# ==============================Game 208=============================
# ~~~~~~~~~~~~Result:  [128.0, -36.0, -36.0, -36.0]
# ==============================Game 209=============================
# ~~~~~~~~~~~~Result:  [-10.0, -20.0, 60.0, -10.0]
# ==============================Game 210=============================
# ~~~~~~~~~~~~Result:  [-30.0, 120.0, -60.0, -30.0]
# ==============================Game 211=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-145.49763033   12.32227488 -216.58767773   89.09952607]
# 结果M.S.E. [265.52905017 261.51210262 238.08984806 239.39818683]
# 自摸率： 66.438356
# 放铳率： 5.805687
# 和了率： 17.298578
# 副露率： 28.554502
# 立直率： 20.971564
# 立直成功率： 39.548023
# 暗和率： 52.054795
# 流局率： 30.805687
# 平均和牌时还剩几张牌： 22.493151
# 没立直时的放铳率： 4.739336
# 四家无听流局率： 2.369668
# 平均打点：5468
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 212=============================
# ~~~~~~~~~~~~Result:  [-39.0, 0.0, 0.0, 39.0]
# ==============================Game 213=============================
# ~~~~~~~~~~~~Result:  [-52.0, 0.0, 0.0, 62.0]
# ==============================Game 214=============================
# ~~~~~~~~~~~~Result:  [-10.0, 50.0, -20.0, -10.0]
# ==============================Game 215=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 20.0, -10.0]
# ==============================Game 216=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 217=============================
# ~~~~~~~~~~~~Result:  [-20.0, -40.0, -20.0, 90.0]
# ==============================Game 218=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -20.0, 40.0]
# ==============================Game 219=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 220=============================
# ~~~~~~~~~~~~Result:  [-60.0, -30.0, 130.0, -30.0]
# ==============================Game 221=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-232.12669683   -4.07239819 -163.80090498  137.55656109]
# 结果M.S.E. [256.6868223  252.0571709  234.77014436 234.66493848]
# 自摸率： 66.013072
# 放铳率： 5.882353
# 和了率： 17.307692
# 副露率： 28.393665
# 立直率： 20.927602
# 立直成功率： 40.000000
# 暗和率： 51.633987
# 流局率： 30.769231
# 平均和牌时还剩几张牌： 22.666667
# 没立直时的放铳率： 4.864253
# 四家无听流局率： 2.262443
# 平均打点：5473
# ~~~~~~~~~~~~Result:  [0.0, 49.0, -39.0, 0.0]
# ==============================Game 222=============================
# ~~~~~~~~~~~~Result:  [-5.0, 30.0, -10.0, -5.0]
# ==============================Game 223=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 224=============================
# ~~~~~~~~~~~~Result:  [0.0, 140.0, -120.0, 0.0]
# ==============================Game 225=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 226=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 227=============================
# ~~~~~~~~~~~~Result:  [-5.0, 40.0, -5.0, -10.0]
# ==============================Game 228=============================
# ~~~~~~~~~~~~Result:  [-10.0, -5.0, 20.0, -5.0]
# ==============================Game 229=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 230=============================
# ~~~~~~~~~~~~Result:  [-10.0, 50.0, -20.0, -10.0]
# ==============================Game 231=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-250.21645022  121.21212121 -247.18614719  112.12121212]
# 结果M.S.E. [246.03973278 250.0098782  232.338742   224.84108611]
# 自摸率： 65.625000
# 放铳率： 5.952381
# 和了率： 17.316017
# 副露率： 28.138528
# 立直率： 21.103896
# 立直成功率： 39.487179
# 暗和率： 51.875000
# 流局率： 30.735931
# 平均和牌时还剩几张牌： 22.518750
# 没立直时的放铳率： 4.870130
# 四家无听流局率： 2.597403
# 平均打点：5433
# ~~~~~~~~~~~~Result:  [20.0, -5.0, -5.0, -10.0]
# ==============================Game 232=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 233=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 234=============================
# ~~~~~~~~~~~~Result:  [-36.0, -36.0, 118.0, -36.0]
# ==============================Game 235=============================
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, 30.0, -10.0]
# ==============================Game 236=============================
# ~~~~~~~~~~~~Result:  [40.0, 0.0, 0.0, -20.0]
# ==============================Game 237=============================
# ~~~~~~~~~~~~Result:  [10.0, -30.0, 10.0, 10.0]
# ==============================Game 238=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 239=============================
# ~~~~~~~~~~~~Result:  [-29.0, 0.0, 0.0, 39.0]
# ==============================Game 240=============================
# ~~~~~~~~~~~~Result:  [-20.0, 0.0, 0.0, 20.0]
# ==============================Game 241=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-239.8340249    68.04979253 -194.19087137  100.41493776]
# 结果M.S.E. [237.77626588 240.79135212 227.72152695 217.18850544]
# 自摸率： 64.670659
# 放铳率： 6.120332
# 和了率： 17.323651
# 副露率： 28.319502
# 立直率： 21.058091
# 立直成功率： 39.408867
# 暗和率： 52.095808
# 流局率： 30.705394
# 平均和牌时还剩几张牌： 22.598802
# 没立直时的放铳率： 4.979253
# 四家无听流局率： 2.489627
# 平均打点：5359
# ~~~~~~~~~~~~Result:  [-30.0, -60.0, 130.0, -30.0]
# ==============================Game 242=============================
# ~~~~~~~~~~~~Result:  [-3.0, -3.0, -5.0, 11.0]
# ==============================Game 243=============================
# ~~~~~~~~~~~~Result:  [0.0, 20.0, -20.0, 0.0]
# ==============================Game 244=============================
# ~~~~~~~~~~~~Result:  [190.0, -180.0, 0.0, 0.0]
# ==============================Game 245=============================
# ~~~~~~~~~~~~Result:  [10.0, 10.0, 10.0, -30.0]
# ==============================Game 246=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 247=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 248=============================
# ~~~~~~~~~~~~Result:  [0.0, 49.0, -39.0, 0.0]
# ==============================Game 249=============================
# ~~~~~~~~~~~~Result:  [-10.0, -20.0, -10.0, 60.0]
# ==============================Game 250=============================
# ~~~~~~~~~~~~Result:  [80.0, -20.0, -40.0, -20.0]
# ==============================Game 251=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-143.8247012   -35.85657371 -180.07968127   96.812749  ]
# 结果M.S.E. [242.14515173 244.49810956 225.33113638 210.45955601]
# 自摸率： 64.367816
# 放铳率： 6.175299
# 和了率： 17.330677
# 副露率： 28.087649
# 立直率： 20.916335
# 立直成功率： 40.000000
# 暗和率： 51.724138
# 流局率： 30.677291
# 平均和牌时还剩几张牌： 22.545977
# 没立直时的放铳率： 5.079681
# 四家无听流局率： 2.390438
# 平均打点：5431
# ~~~~~~~~~~~~Result:  [-10.0, 40.0, -10.0, -20.0]
# ==============================Game 252=============================
# ~~~~~~~~~~~~Result:  [-40.0, 100.0, -20.0, -20.0]
# ==============================Game 253=============================
# ~~~~~~~~~~~~Result:  [-10.0, -20.0, -10.0, 40.0]
# ==============================Game 254=============================
# ~~~~~~~~~~~~Result:  [-120.0, 0.0, 0.0, 130.0]
# ==============================Game 255=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 50.0, -20.0]
# ==============================Game 256=============================
# ~~~~~~~~~~~~Result:  [-60.0, -30.0, 140.0, -30.0]
# ==============================Game 257=============================
# ~~~~~~~~~~~~Result:  [-16.0, -32.0, 84.0, -16.0]
# ==============================Game 258=============================
# ~~~~~~~~~~~~Result:  [11.0, -3.0, -5.0, -3.0]
# ==============================Game 259=============================
# ~~~~~~~~~~~~Result:  [-30.0, 120.0, -30.0, -60.0]
# ==============================Game 260=============================
# ~~~~~~~~~~~~Result:  [0.0, 40.0, -20.0, 0.0]
# ==============================Game 261=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-255.17241379   32.56704981 -123.75478927   93.48659004]
# 结果M.S.E. [239.51679156 243.76770024 225.63025226 211.08430086]
# 自摸率： 65.027322
# 放铳率： 6.130268
# 和了率： 17.528736
# 副露率： 28.448276
# 立直率： 21.072797
# 立直成功率： 40.000000
# 暗和率： 51.912568
# 流局率： 29.885057
# 平均和牌时还剩几张牌： 22.371585
# 没立直时的放铳率： 5.076628
# 四家无听流局率： 2.298851
# 平均打点：5478
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 262=============================
# ~~~~~~~~~~~~Result:  [-3.0, -3.0, -5.0, 21.0]
# ==============================Game 263=============================
# ~~~~~~~~~~~~Result:  [-5.0, 30.0, -5.0, -10.0]
# ==============================Game 264=============================
# ~~~~~~~~~~~~Result:  [-20.0, 60.0, -10.0, -10.0]
# ==============================Game 265=============================
# ~~~~~~~~~~~~Result:  [-5.0, -10.0, -5.0, 30.0]
# ==============================Game 266=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 267=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, -20.0, 70.0]
# ==============================Game 268=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 269=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 270=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 271=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-265.31365314   45.01845018 -143.17343173  116.23616236]
# 结果M.S.E. [231.16524564 235.98213761 217.52962735 204.83090578]
# 自摸率： 65.608466
# 放铳率： 5.996310
# 和了率： 17.435424
# 副露率： 28.505535
# 立直率： 20.940959
# 立直成功率： 40.528634
# 暗和率： 51.322751
# 流局率： 30.258303
# 平均和牌时还剩几张牌： 22.264550
# 没立直时的放铳率： 4.981550
# 四家无听流局率： 3.321033
# 平均打点：5405
# ~~~~~~~~~~~~Result:  [-36.0, -36.0, -36.0, 118.0]
# ==============================Game 272=============================
# ~~~~~~~~~~~~Result:  [-52.0, 0.0, 0.0, 52.0]
# ==============================Game 273=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 274=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, 80.0, -20.0]
# ==============================Game 275=============================
# ~~~~~~~~~~~~Result:  [10.0, -30.0, 10.0, 10.0]
# ==============================Game 276=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 277=============================
# ~~~~~~~~~~~~Result:  [-20.0, 70.0, -20.0, -20.0]
# ==============================Game 278=============================
# ~~~~~~~~~~~~Result:  [-5.0, 40.0, -10.0, -5.0]
# ==============================Game 279=============================
# ~~~~~~~~~~~~Result:  [100.0, -20.0, -20.0, -40.0]
# ==============================Game 280=============================
# ~~~~~~~~~~~~Result:  [-10.0, -5.0, 20.0, -5.0]
# ==============================Game 281=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-288.96797153   39.50177936 -125.97864769  122.77580071]
# 结果M.S.E. [227.33657075 230.01471869 212.17606984 203.35748443]
# 自摸率： 66.326531
# 放铳率： 5.871886
# 和了率： 17.437722
# 副露率： 28.647687
# 立直率： 21.263345
# 立直成功率： 39.748954
# 暗和率： 51.530612
# 流局率： 30.249110
# 平均和牌时还剩几张牌： 22.142857
# 没立直时的放铳率： 4.893238
# 四家无听流局率： 3.202847
# 平均打点：5442
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 282=============================
# ~~~~~~~~~~~~Result:  [10.0, 10.0, 10.0, -30.0]
# ==============================Game 283=============================
# ~~~~~~~~~~~~Result:  [-10.0, 40.0, -10.0, -20.0]
# ==============================Game 284=============================
# ~~~~~~~~~~~~Result:  [118.0, -36.0, -36.0, -36.0]
# ==============================Game 285=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 49.0, -39.0]
# ==============================Game 286=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, 70.0, -20.0]
# ==============================Game 287=============================
# ~~~~~~~~~~~~Result:  [90.0, -20.0, -20.0, -40.0]
# ==============================Game 288=============================
# ~~~~~~~~~~~~Result:  [0.0, 20.0, -10.0, 0.0]
# ==============================Game 289=============================
# ~~~~~~~~~~~~Result:  [0.0, -26.0, 0.0, 36.0]
# ==============================Game 290=============================
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, -10.0, 20.0]
# ==============================Game 291=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-235.05154639   16.83848797 -101.71821306   72.50859107]
# 结果M.S.E. [225.32534874 223.50372521 207.68040998 198.93494442]
# 自摸率： 66.009852
# 放铳率： 5.927835
# 和了率： 17.439863
# 副露率： 28.780069
# 立直率： 21.134021
# 立直成功率： 39.430894
# 暗和率： 52.216749
# 流局率： 30.240550
# 平均和牌时还剩几张牌： 22.054187
# 没立直时的放铳率： 4.982818
# 四家无听流局率： 3.092784
# 平均打点：5443
# ~~~~~~~~~~~~Result:  [-20.0, 90.0, -20.0, -40.0]
# ==============================Game 292=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 293=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 294=============================
# ~~~~~~~~~~~~Result:  [90.0, -20.0, -40.0, -20.0]
# ==============================Game 295=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, -15.0, 15.0]
# ==============================Game 296=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 20.0, -20.0]
# ==============================Game 297=============================
# ~~~~~~~~~~~~Result:  [-20.0, -40.0, -20.0, 90.0]
# ==============================Game 298=============================
# ~~~~~~~~~~~~Result:  [-5.0, 30.0, -10.0, -5.0]
# ==============================Game 299=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 300=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 49.0, -39.0]
# ==============================Game 301=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-227.24252492   24.58471761 -103.65448505   57.14285714]
# 结果M.S.E. [219.82002197 218.63388491 202.30692297 195.50633081]
# 自摸率： 66.028708
# 放铳率： 5.897010
# 和了率： 17.358804
# 副露率： 28.903654
# 立直率： 21.096346
# 立直成功率： 39.763780
# 暗和率： 51.674641
# 流局率： 30.564784
# 平均和牌时还剩几张牌： 22.090909
# 没立直时的放铳率： 4.983389
# 四家无听流局率： 2.990033
# 平均打点：5444
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 302=============================
# ~~~~~~~~~~~~Result:  [-30.0, 130.0, -60.0, -30.0]
# ==============================Game 303=============================
# ~~~~~~~~~~~~Result:  [-20.0, 110.0, -20.0, -40.0]
# ==============================Game 304=============================
# ~~~~~~~~~~~~Result:  [-40.0, 90.0, -20.0, -20.0]
# ==============================Game 305=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 306=============================
# ~~~~~~~~~~~~Result:  [-5.0, 30.0, -10.0, -5.0]
# ==============================Game 307=============================
# ~~~~~~~~~~~~Result:  [-116.0, 0.0, 0.0, 126.0]
# ==============================Game 308=============================
# ~~~~~~~~~~~~Result:  [150.0, -40.0, -40.0, -40.0]
# ==============================Game 309=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 20.0, -10.0]
# ==============================Game 310=============================
# ~~~~~~~~~~~~Result:  [-64.0, 0.0, 0.0, 64.0]
# ==============================Game 311=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-269.77491961  117.04180064 -148.55305466   60.12861736]
# 结果M.S.E. [222.25130358 219.77485325 197.78178826 195.55141846]
# 自摸率： 65.898618
# 放铳率： 5.948553
# 和了率： 17.443730
# 副露率： 28.858521
# 立直率： 21.302251
# 立直成功率： 40.000000
# 暗和率： 51.152074
# 流局率： 30.225080
# 平均和牌时还剩几张牌： 22.032258
# 没立直时的放铳率： 5.064309
# 四家无听流局率： 3.536977
# 平均打点：5552
# ...
# 和了率： 17.288438
# 副露率： 28.692367
# 立直率： 20.347873
# 立直成功率： 39.865235
# 暗和率： 53.080044
# 流局率： 30.846247
# 平均和牌时还剩几张牌： 23.399023
# 没立直时的放铳率： 5.568841
# 四家无听流局率： 2.072572
# 平均打点：5635
# ~~~~~~~~~~~~Result:  [-20.0, -40.0, -20.0, 100.0]
# ==============================Game 15682=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -20.0, 50.0]
# ==============================Game 15683=============================
# ~~~~~~~~~~~~Result:  [89.0, -20.0, -20.0, -39.0]
# ==============================Game 15684=============================
# ~~~~~~~~~~~~Result:  [-39.0, -20.0, 89.0, -20.0]
# ==============================Game 15685=============================
# ~~~~~~~~~~~~Result:  [-20.0, -39.0, -20.0, 89.0]
# ==============================Game 15686=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 68.0, -58.0]
# ==============================Game 15687=============================
# ~~~~~~~~~~~~Result:  [-5.0, 40.0, -5.0, -10.0]
# ==============================Game 15688=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 15689=============================
# ~~~~~~~~~~~~Result:  [62.0, -52.0, 0.0, 0.0]
# ==============================Game 15690=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 15691=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-105.21955261  -23.47842712 -149.58893633   31.52125422]
# 结果M.S.E. [29.75372238 29.99978593 29.44046166 30.01965697]
# 自摸率： 61.887210
# 放铳率： 6.589765
# 和了率： 17.290166
# 副露率： 28.683640
# 立直率： 20.355618
# 立直成功率： 39.887289
# 暗和率： 53.040914
# 流局率： 30.839335
# 平均和牌时还剩几张牌： 23.395872
# 没立直时的放铳率： 5.568479
# 四家无听流局率： 2.071251
# 平均打点：5636
# ~~~~~~~~~~~~Result:  [-48.0, 0.0, 0.0, 48.0]
# ==============================Game 15692=============================
# ~~~~~~~~~~~~Result:  [-26.0, 0.0, 0.0, 36.0]
# ==============================Game 15693=============================
# ~~~~~~~~~~~~Result:  [0.0, 49.0, -39.0, 0.0]
# ==============================Game 15694=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 15695=============================
# ~~~~~~~~~~~~Result:  [0.0, 20.0, -10.0, 0.0]
# ==============================Game 15696=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 15697=============================
# ~~~~~~~~~~~~Result:  [-20.0, -40.0, -20.0, 90.0]
# ==============================Game 15698=============================
# ~~~~~~~~~~~~Result:  [-20.0, 89.0, -39.0, -20.0]
# ==============================Game 15699=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 15700=============================
# ~~~~~~~~~~~~Result:  [-120.0, 0.0, 0.0, 130.0]
# ==============================Game 15701=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-106.61104388  -23.18960576 -149.95860136   32.9596841 ]
# 结果M.S.E. [29.7489096  29.98758375 29.42465493 30.01700063]
# 自摸率： 61.860037
# 放铳率： 6.595121
# 和了率： 17.291892
# 副露率： 28.679702
# 立直率： 20.356984
# 立直成功率： 39.906140
# 暗和率： 53.020258
# 流局率： 30.832431
# 平均和牌时还剩几张牌： 23.393923
# 没立直时的放铳率： 5.572893
# 四家无听流局率： 2.069932
# 平均打点：5635
# ~~~~~~~~~~~~Result:  [20.0, -10.0, -5.0, -5.0]
# ==============================Game 15702=============================
# ~~~~~~~~~~~~Result:  [-26.0, -26.0, 98.0, -26.0]
# ==============================Game 15703=============================
# ~~~~~~~~~~~~Result:  [0.0, 33.0, -13.0, 0.0]
# ==============================Game 15704=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 15705=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 15706=============================
# ~~~~~~~~~~~~Result:  [-60.0, -60.0, 190.0, -60.0]
# ==============================Game 15707=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 15708=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 90.0, -80.0]
# ==============================Game 15709=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 15710=============================
# ~~~~~~~~~~~~Result:  [-60.0, -60.0, 190.0, -60.0]
# ==============================Game 15711=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-107.44064668  -24.49875883 -146.3305964    31.37292343]
# 结果M.S.E. [29.73622905 29.97599949 29.46657886 30.00811344]
# 自摸率： 61.862691
# 放铳率： 6.594106
# 和了率： 17.290433
# 副露率： 28.685316
# 立直率： 20.361530
# 立直成功率： 39.887465
# 暗和率： 53.027793
# 流局率： 30.838266
# 平均和牌时还剩几张牌： 23.392141
# 没立直时的放铳率： 5.572529
# 四家无听流局率： 2.074979
# 平均打点：5638
# ~~~~~~~~~~~~Result:  [10.0, -10.0, 0.0, 0.0]
# ==============================Game 15712=============================
# ~~~~~~~~~~~~Result:  [10.0, 10.0, 10.0, -30.0]
# ==============================Game 15713=============================
# ~~~~~~~~~~~~Result:  [11.0, -5.0, -3.0, -3.0]
# ==============================Game 15714=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -20.0, 50.0]
# ==============================Game 15715=============================
# ~~~~~~~~~~~~Result:  [-116.0, 0.0, 0.0, 126.0]
# ==============================Game 15716=============================
# ~~~~~~~~~~~~Result:  [0.0, 49.0, -39.0, 0.0]
# ==============================Game 15717=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 15718=============================
# ~~~~~~~~~~~~Result:  [-30.0, -30.0, -60.0, 130.0]
# ==============================Game 15719=============================
# ~~~~~~~~~~~~Result:  [0.0, 62.0, -52.0, 0.0]
# ==============================Game 15720=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -5.0, -5.0]
# ==============================Game 15721=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-108.13561478  -23.90433179 -147.53514407   32.83506138]
# 结果M.S.E. [29.72742514 29.96140207 29.45381589 30.0101779 ]
# 自摸率： 61.853964
# 放铳率： 6.596273
# 和了率： 17.292157
# 副露率： 28.687743
# 立直率： 20.358120
# 立直成功率： 39.900016
# 暗和率： 53.025566
# 流局率： 30.831372
# 平均和牌时还剩几张牌： 23.386794
# 没立直时的放铳率： 5.575345
# 四家无听流局率： 2.073659
# 平均打点：5638
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 15722=============================
# ~~~~~~~~~~~~Result:  [-10.0, 60.0, -20.0, -10.0]
# ==============================Game 15723=============================
# ~~~~~~~~~~~~Result:  [-40.0, -40.0, -40.0, 130.0]
# ==============================Game 15724=============================
# ~~~~~~~~~~~~Result:  [10.0, -30.0, 10.0, 10.0]
# ==============================Game 15725=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 15726=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 15727=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, -20.0, 70.0]
# ==============================Game 15728=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 15729=============================
# ~~~~~~~~~~~~Result:  [-5.0, -10.0, -5.0, 40.0]
# ==============================Game 15730=============================
# ~~~~~~~~~~~~Result:  [0.0, 90.0, -80.0, 0.0]
# ==============================Game 15731=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-108.63899307  -23.85735173 -148.77630157   34.37162291]
# 结果M.S.E. [29.71000131 29.95182047 29.44253901 30.00488249]
# 自摸率： 61.862304
# 放铳率： 6.593669
# 和了率： 17.289111
# 副露率： 28.682220
# 立直率： 20.364249
# 立直成功率： 39.893866
# 暗和率： 53.010387
# 流局率： 30.843557
# 平均和牌时还剩几张牌： 23.383859
# 没立直时的放铳率： 5.571801
# 四家无听流局率： 2.072341
# 平均打点：5638
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 15732=============================
# ~~~~~~~~~~~~Result:  [-39.0, -20.0, -20.0, 99.0]
# ==============================Game 15733=============================
# ~~~~~~~~~~~~Result:  [-20.0, -39.0, 79.0, -20.0]
# ==============================Game 15734=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 15735=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 15736=============================
# ~~~~~~~~~~~~Result:  [-5.0, -3.0, -3.0, 11.0]
# ==============================Game 15737=============================
# ~~~~~~~~~~~~Result:  [-13.0, -26.0, -13.0, 62.0]
# ==============================Game 15738=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, 60.0, -20.0]
# ==============================Game 15739=============================
# ~~~~~~~~~~~~Result:  [80.0, -80.0, 0.0, 0.0]
# ==============================Game 15740=============================
# ~~~~~~~~~~~~Result:  [140.0, -120.0, 0.0, 0.0]
# ==============================Game 15741=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-108.04269106  -25.7988692  -148.15450098   35.06130487]
# 结果M.S.E. [29.70963232 29.94883557 29.43178729 29.99528083]
# 自摸率： 61.871957
# 放铳率： 6.592656
# 和了率： 17.290833
# 副露率： 28.684645
# 立直率： 20.364018
# 立直成功率： 39.884573
# 暗和率： 53.026545
# 流局率： 30.836669
# 平均和牌时还剩几张牌： 23.381005
# 没立直时的放铳率： 5.571438
# 四家无听流局率： 2.071025
# 平均打点：5639
# ~~~~~~~~~~~~Result:  [-20.0, -40.0, -20.0, 100.0]
# ==============================Game 15742=============================
# ~~~~~~~~~~~~Result:  [-20.0, -20.0, 60.0, -20.0]
# ==============================Game 15743=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 15744=============================
# ~~~~~~~~~~~~Result:  [-40.0, -20.0, 100.0, -20.0]
# ==============================Game 15745=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 15746=============================
# ~~~~~~~~~~~~Result:  [50.0, -10.0, -20.0, -10.0]
# ==============================Game 15747=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 15748=============================
# ~~~~~~~~~~~~Result:  [-20.0, 0.0, 0.0, 20.0]
# ==============================Game 15749=============================
# ~~~~~~~~~~~~Result:  [-5.0, -10.0, 20.0, -5.0]
# ==============================Game 15750=============================
# ~~~~~~~~~~~~Result:  [56.0, -26.0, 0.0, 0.0]
# ==============================Game 15751=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-108.25344423  -26.67767126 -147.20335217   35.3564853 ]
# 结果M.S.E. [29.69537378 29.93409565 29.42244997 29.98283621]
# 自摸率： 61.878098
# 放铳率： 6.591645
# 和了率： 17.290966
# 副露率： 28.685480
# 立直率： 20.363786
# 立直成功率： 39.890881
# 暗和率： 53.020011
# 流局率： 30.836137
# 平均和牌时还剩几张牌： 23.380485
# 没立直时的放铳率： 5.569488
# 四家无听流局率： 2.076059
# 平均打点：5639
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 40.0]
# ==============================Game 15752=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 40.0, -20.0]
# ==============================Game 15753=============================
# ~~~~~~~~~~~~Result:  [-5.0, -10.0, -5.0, 20.0]
# ==============================Game 15754=============================
# ~~~~~~~~~~~~Result:  [-39.0, 0.0, 0.0, 49.0]
# ==============================Game 15755=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 15756=============================
# ~~~~~~~~~~~~Result:  [-39.0, 89.0, -20.0, -20.0]
# ==============================Game 15757=============================
# ~~~~~~~~~~~~Result:  [-120.0, 0.0, 0.0, 130.0]
# ==============================Game 15758=============================
# ~~~~~~~~~~~~Result:  [10.0, -30.0, 10.0, 10.0]
# ==============================Game 15759=============================
# ~~~~~~~~~~~~Result:  [-20.0, 90.0, -20.0, -40.0]
# ==============================Game 15760=============================
# ~~~~~~~~~~~~Result:  [-15.0, 15.0, 15.0, -15.0]
# ==============================Game 15761=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-109.94860732  -25.74709727 -147.3002982    36.12080452]
# 结果M.S.E. [29.6891979  29.92502063 29.40507128 29.97780779]
# 自摸率： 61.875057
# 放铳率： 6.592221
# 和了率： 17.291098
# 副露率： 28.678383
# 立直率： 20.368314
# 立直成功率： 39.895647
# 暗和率： 53.004312
# 流局率： 30.835607
# 平均和牌时还剩几张牌： 23.374645
# 没立直时的放铳率： 5.569126
# 四家无听流局率： 2.074741
# 平均打点：5639
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 15762=============================
# ~~~~~~~~~~~~Result:  [-52.0, 0.0, 0.0, 62.0]
# ==============================Game 15763=============================
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, -5.0, 25.0]
# ==============================Game 15764=============================
# ~~~~~~~~~~~~Result:  [10.0, 10.0, 10.0, -30.0]
# ==============================Game 15765=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 15766=============================
# ~~~~~~~~~~~~Result:  [-3.0, 21.0, -5.0, -3.0]
# ==============================Game 15767=============================
# ~~~~~~~~~~~~Result:  [-40.0, 170.0, -40.0, -80.0]
# ==============================Game 15768=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 15769=============================
# ~~~~~~~~~~~~Result:  [-20.0, -40.0, 80.0, -20.0]
# ==============================Game 15770=============================
# ~~~~~~~~~~~~Result:  [13.0, -13.0, 0.0, 0.0]
# ==============================Game 15771=============================
# ------------------------- Statistics ----------------------
# 平均结果: [-110.05009194  -25.07767421 -147.27030626   35.55259654]
# 结果M.S.E. [29.67535871 29.9250548  29.39254279 29.96644873]
# 自摸率： 61.881188
# 放铳率： 6.591212
# 和了率： 17.291231
# 副露率： 28.677636
# 立直率： 20.364910
# 立直成功率： 39.892582
# 暗和率： 53.016135
# 流局率： 30.835077
# 平均和牌时还剩几张牌： 23.373212
# 没立直时的放铳率： 5.568765
# 四家无听流局率： 2.073426
# 平均打点：5639
# ~~~~~~~~~~~~Result:  [-20.0, 89.0, -20.0, -39.0]
# ==============================Game 15772=============================
# ~~~~~~~~~~~~Result:  [-5.0, 11.0, -3.0, -3.0]
# ==============================Game 15773=============================
# ~~~~~~~~~~~~Result:  [-15.0, -15.0, 15.0, 15.0]
# ==============================Game 15774=============================
# ~~~~~~~~~~~~Result:  [-40.0, -40.0, 130.0, -40.0]
# ==============================Game 15775=============================
# ~~~~~~~~~~~~Result:  [10.0, 10.0, -30.0, 10.0]
# ==============================Game 15776=============================
# ~~~~~~~~~~~~Result:  [-5.0, -3.0, -3.0, 11.0]
# ==============================Game 15777=============================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-11204d4d10dd> in <module>
#      32             #     a = valid_actions[np.random.randint(len(valid_actions))]
#      33
# ---> 34             valid_actions = env_test.get_valid_actions(nhot=False)
#      35
#      36             if len(valid_actions) == 1:
#
# C:\Code\mahjong\AI\wrapper.py in get_valid_actions(self, nhot)
#     395         # gva_time = time.time()
#     396
# --> 397         self.update_hand_and_latest_tiles()
#     398
#     399         self.curr_valid_actions = []
#
# C:\Code\mahjong\AI\wrapper.py in update_hand_and_latest_tiles(self)
#     652                             self.hand_tiles[pid].append(int(self.t.players[pid].hand[i].tile) * 4)
#     653                         else:
# --> 654                             self.hand_tiles[pid].append(int(self.t.players[pid].hand[i].tile) * 4 + 3)
#     655
#     656                 # hand_tiles_id_player = np.array([int(ht / 4) for ht in self.hand_tiles[playerNo]])
#
# KeyboardInterrupt:

# %%
total_results_array = np.array(total_results)
sampled_games = np.zeros([10000, 8, 4])
for i in range(10000):
    sampled_games[i] = total_results_array[np.random.choice(len(total_results_array), 8)]
sampled_match_results = sampled_games.sum(-2)

win_rate = ((sampled_games[:, :, 0] + sampled_games[:, :, 1]).sum(1) > (sampled_games[:, :, 2] + sampled_games[:, :, 3]).sum(1)).mean(0) 
print(win_rate)

# %%
for pid in range(4):
    print(np.mean(np.argmax(sampled_match_results, axis=-1) == pid) * 100, np.std(np.argmax(sampled_match_results, axis=-1) == pid) / 10000 ** 0.5 * 100)

# %%
np.array(total_results).std(axis=0) * 100 / np.sqrt(game)

# %%
to_unicode_tails(env_test.hand_tiles[3])

# %%
plt.pcolor(env_test.get_obs(3)[:6, :])
plt.show()

# %%
env_test.can_riichi_tiles_id

# %%
for act in env_test.t.get_self_actions():
    print(act.action)
    print(int(act.correspond_tiles[0].tile))

# %%
env_test.riichi_tile_id

# %%
int(env_test.t.get_selected_action_tile().tile)

# %%
env_test.t.get_response_actions()[0].action

# %%
env_test.t.players[curr_pid].hand.__len__()

# %%
env_test.Phases[env_test.t.get_phase()]

# %%
env_test.hand_tiles[curr_pid]

# %%
env_test.can_riichi

# %%
env_test.t.get_self_actions()[0].action

# %%
a = set([1,2,3,4,4])

# %%
list(a)

# %%
mp.Action.Kakan
