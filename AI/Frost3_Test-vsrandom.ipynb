# %%
from wrapper import *
import MahjongPy as mp
import os
import time
import logging
import warnings

import numpy as np
import scipy.io as sio
import torch
import matplotlib.pyplot as plt


from models import VLOG

# %%
# player_i_hand_start_ind = [0, 63, 69, 75]  # later 3 in oracle_obs
# player_i_side_start_ind = [6, 12, 18, 24]
# player_i_river_start_ind = [30, 37, 44, 51]

# dora_indicator_ind = 58
# dora_ind = 59
# game_wind_ind = 60
# self_wind_ind = 61
# latest_tile_ind = 62

# aka_tile_ints = [16, 16 + 36, 16 + 36 + 36]
# player_obs_width = 63

# CHILEFT = 34
# CHIMIDDLE = 35
# CHIRIGHT = 36
# PON = 37
# ANKAN = 38
# MINKAN = 39
# ADDKAN = 40

# RIICHI = 41
# RON = 42
# TSUMO = 43
# PUSH = 44
# NOOP = 45

# %%
UNICODE_TILES = """
    🀇 🀈 🀉 🀊 🀋 🀌 🀍 🀎 🀏 
    🀙 🀚 🀛 🀜 🀝 🀞 🀟 🀠 🀡
    🀐 🀑 🀒 🀓 🀔 🀕 🀖 🀗 🀘
    🀀 🀁 🀂 🀃
    🀆 🀅 🀄
""".split()

EXPLAINS = UNICODE_TILES + ["Chi-Left", "Chi-Middle", "Chi-Right", "Pon", "An-Kan",
           "Min-Kan", "Add-Kan", "Riichi", "Ron", "Tsumo", "Push 99", "Pass", "Pass"]


def to_unicode_tails(tiles, sort=True):
    unicode_tail_string = ""
    if sort:
        tiles = np.sort(np.array(tiles))

    for tile in tiles:
        unicode_tail_string = unicode_tail_string + UNICODE_TILES[int(tile / 4)]

    return unicode_tail_string

# %%
env_test = EnvMahjong3(force_riichi=False, force_win=True, append_aval_action_obs=True)
max_steps = 1000

# %%
# agent_test0 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_0.model")
# agent_test1 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_1.model")
# agent_test2 = torch.load("C:/code/snake/amlt/vlog_offlinemj_20210724/search_envid_1_beta_1e-05_alpha_1_kldt_10_cqla_10/data/mahjong_VLOG_DDQN_2.model")
# agent_test = torch.load("./vlog_offlinemj_20210724/search_envid_1_beta_0_alpha_1_kldt_-1_cqla_100/data/mahjong_VLOG_DDQN_0.model")


if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"


# agent_test0 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test1 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))
# agent_test2 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test3 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))

# agent_test0 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_0.model", map_location=torch.device(device))
# agent_test1 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_1e-06_alpha_1_kldt_10_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_1.model", map_location=torch.device(device))
# agent_test2 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_0_alpha_1_kldt_-1_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_2.model", map_location=torch.device(device))
# agent_test3 = torch.load("./vlog_offlinemj_bc_20210802/search_beta_0_alpha_1_kldt_-1_bnt_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_3.model", map_location=torch.device(device))


agent_test0 = torch.load("./vlog_offlinemj_bc_20210807/search_envid_1_beta_0_alpha_1_kldt_10_bnt_0_dpo_0.25_eqn_1_cqla_0/data/mahjong_VLOG_BC_2.model", map_location=torch.device(device))
agent_test1 = torch.load("./vlog_offlinemj_bc_20210807/search_envid_1_beta_0_alpha_1_kldt_10_bnt_0_dpo_0.25_eqn_1_cqla_0/data/mahjong_VLOG_BC_3.model", map_location=torch.device(device))
agent_test2 = torch.load("./vlog_offlinemj_bc_20210807/search_envid_1_beta_0_alpha_1_kldt_10_bnt_0_dpo_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_2.model", map_location=torch.device(device))
agent_test3 = torch.load("./vlog_offlinemj_bc_20210807/search_envid_1_beta_0_alpha_1_kldt_10_bnt_0_dpo_0_eqn_1_cqla_0/data/mahjong_VLOG_BC_3.model", map_location=torch.device(device))

# %%
agents_test = [agent_test0, agent_test1, agent_test2, agent_test3]

for agent in agents_test:
    agent.device = device

# %%
full_obs = False

# %%
EpiTestRet = 0
steps_taken = 0

game = 0

tsumo_times = 0
houjyu_times = 0

fulu_times = 0

agari_times = 0
agari_scores = []

total_results = []

while game < 20000:
    print("==============================Game {}=============================".format(game))
    # reset each episode
    if game % 10 == 1:
        try:
            print("------------------------- Statistics ----------------------")
            print("平均结果:", (np.mean(np.array(total_results), axis=0)))
            print("结果M.S.E.", np.array(total_results).std(axis=0) / np.sqrt(game))
            print("自摸率： %f " % (tsumo_times * 100 / agari_times))
            print("放铳率： %f " % (houjyu_times * 100 / game ))
            print("和了率： %f " % (agari_times * 100 / game ))
            print("副露率： %f " % (fulu_times * 100 / game ))
            print("平均打点：%d " % (np.mean(agari_scores)))
        except:
            pass
    try:
        sp = env_test.reset(game % 4, 'east')
        result_array = np.zeros([4])
        done = False

        for tt in range(max_steps):

            # if curr_pid != 0:
            #     a = valid_actions[np.random.randint(len(valid_actions))]

            valid_actions = env_test.get_valid_actions(nhot=False)

            if len(valid_actions) == 1:
                env_test.t.make_selection(0)

            else:
                curr_pid = env_test.get_curr_player_id()

                action_mask = env_test.get_valid_actions(nhot=True)
                
                if curr_pid == 0:
                    
                    if not full_obs:
                        a = agents_test[curr_pid].select(env_test.get_obs(curr_pid), action_mask, greedy=True)
                    else:
                        a = agents_test[curr_pid].select(env_test.get_full_obs(curr_pid), action_mask, greedy=True)
                else:
                    
                    a = valid_actions[np.random.randint(len(valid_actions))]
                    
                
#                 if a == TSUMO:
#                     print(env_test.get_full_obs(0)[player_i_river_start_ind[curr_pid]:player_i_river_start_ind[curr_pid] + 7,  int(env_test.latest_tile / 4)])
#                     plt.pcolor(env_test.get_obs(curr_pid))
#                     plt.show()

                # if curr_pid == 0 and len(valid_actions) > 1:
                #     print("-------------- Step {}, player {} ----------------".format(tt, curr_pid))
                #     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
                #     side_tiles_0 = [st[0] for st in env_test.side_tiles[curr_pid]]
                #     print("手牌: ", to_unicode_tails(env_test.hand_tiles[curr_pid]),
                #           "； 副露：", to_unicode_tails(side_tiles_0))
                #     if a < 34:
                #         agent_selection_str = UNICODE_TILES[a]
                #     else:
                #         agent_selection_str = EXPLAINS[a]
                #
                #     print("Agent选择打: ", agent_selection_str)

                sp, r, done, _ = env_test.step(curr_pid, a)
                if r < 0 and not done:
                    result_array[curr_pid] += r * 100

            steps_taken += 1

            if done or env_test.t.get_phase() == 16:
                payoffs = env_test.get_payoffs()
                # EpiTestRet += payoffs[0]
                result_array += np.array(payoffs) * 100
                print("~~~~~~~~~~~~Result: ", payoffs)
                total_results.append(result_array)
                
                if len(env_test.side_tiles[0]) >= 3:
                    fulu_times += 1
                        
                if np.count_nonzero(result_array < 0) < 3 and payoffs[0] < 0:
                    houjyu_times += 1
                
                if env_test.t.get_remain_tile() > 0 and payoffs[0] > 0:  # not 流局
#                     print(env_test.t.get_remain_tile())
                    
                    if np.count_nonzero(result_array < 0) == 3:
                        tsumo_times += 1
                    
                    agari_times += 1
                    agari_scores.append(np.max(result_array))
                    
#                     win_pid = np.argmax(result_array)
#                     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
#                     side_tiles_0 = [st[0] for st in env_test.side_tiles[win_pid]]
#                     print("手牌: ", to_unicode_tails(env_test.hand_tiles[win_pid]),
#                           "； 副露：", to_unicode_tails(side_tiles_0))

                # print(env_test.t.game_log.to_string())
#                 if np.max(payoffs) > 0:
#                     plt.pcolor(sp)
#                     plt.show()
#                     print(env_test.Phases[env_test.t.get_phase()], "Recent Tile:", to_unicode_tails([env_test.latest_tile]))
#                     side_tiles_0 = [st[0] for st in env_test.side_tiles[np.argmax(payoffs)]]
#                     print("手牌: ", to_unicode_tails(env_test.hand_tiles[np.argmax(payoffs)]),
#                       "； 副露：", to_unicode_tails(side_tiles_0))
                break

#             if not done and env_test.t.get_phase() == 0:
#                 shanten_num = np.zeros(4)
#                 for pid in range(4):
#                     shanten_num[pid] = shanten.calculate_shanten(TilesConverter.to_34_array(
#                         env_test.hand_tiles[pid] + [st[0] for st in env_test.side_tiles[pid]]))
#                 print("向听数:", shanten_num)
        game += 1

    except Exception as e:
        print(e)
        if a < 34:
            agent_selection_str = UNICODE_TILES[a]
        else:
            agent_selection_str = EXPLAINS[a]
        print("Agent选择打: ", a)
        time.sleep(0.1)
        continue
# Out:
# ==============================Game 0=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 1=============================
# ------------------------- Statistics ----------------------
# 平均结果: [0. 0. 0. 0.]
# 结果M.S.E. [0. 0. 0. 0.]
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 2=============================
# ~~~~~~~~~~~~Result:  [40.0, -10.0, -20.0, -10.0]
# ==============================Game 3=============================
# ~~~~~~~~~~~~Result:  [11.0, -3.0, -3.0, -5.0]
# ==============================Game 4=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 5=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, 15.0, -15.0]
# ==============================Game 6=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 7=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 8=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 9=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 10=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 11=============================
# ------------------------- Statistics ----------------------
# 平均结果: [1327.27272727 -527.27272727 -345.45454545 -545.45454545]
# 结果M.S.E. [427.19359211 164.68899269 257.56765503 163.31465161]
# 自摸率： 100.000000
# 放铳率： 0.000000
# 和了率： 18.181818
# 副露率： 45.454545
# 平均打点：2550
# ~~~~~~~~~~~~Result:  [80.0, -20.0, -20.0, -40.0]
# ==============================Game 12=============================
# ~~~~~~~~~~~~Result:  [118.0, -36.0, -36.0, -36.0]
# ==============================Game 13=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 14=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 15=============================
# ~~~~~~~~~~~~Result:  [130.0, -30.0, -30.0, -60.0]
# ==============================Game 16=============================
# ~~~~~~~~~~~~Result:  [130.0, -120.0, 0.0, 0.0]
# ==============================Game 17=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -5.0, -5.0]
# ==============================Game 18=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 20=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 21=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 3066.66666667 -1447.61904762  -757.14285714  -909.52380952]
# 结果M.S.E. [872.36050437 555.92537092 245.18690437 384.91420618]
# 自摸率： 85.714286
# 放铳率： 0.000000
# 和了率： 33.333333
# 副露率： 33.333333
# 平均打点：7128
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 22=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 23=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 24=============================
# ~~~~~~~~~~~~Result:  [58.0, -58.0, 0.0, 0.0]
# ==============================Game 25=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 26=============================
# ~~~~~~~~~~~~Result:  [62.0, -52.0, 0.0, 0.0]
# ==============================Game 27=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 28=============================
# ~~~~~~~~~~~~Result:  [58.0, -58.0, 0.0, 0.0]
# ==============================Game 29=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 30=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 31=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2909.67741935 -1683.87096774  -609.67741935  -712.90322581]
# 结果M.S.E. [633.74339747 448.9807343  176.76447105 269.8032557 ]
# 自摸率： 54.545455
# 放铳率： 0.000000
# 和了率： 35.483871
# 副露率： 38.709677
# 平均打点：6245
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 32=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 33=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 34=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 35=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 36=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 37=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 38=============================
# ~~~~~~~~~~~~Result:  [36.0, -26.0, 0.0, 0.0]
# ==============================Game 39=============================
# ~~~~~~~~~~~~Result:  [90.0, -80.0, 0.0, 0.0]
# ==============================Game 40=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 41=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2702.43902439 -1629.26829268  -558.53658537  -636.58536585]
# 结果M.S.E. [514.94601353 383.74534088 139.59981939 208.52606157]
# 自摸率： 46.153846
# 放铳率： 0.000000
# 和了率： 31.707317
# 副露率： 31.707317
# 平均打点：6100
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 42=============================
# ~~~~~~~~~~~~Result:  [20.0, -10.0, 0.0, 0.0]
# ==============================Game 43=============================
# ~~~~~~~~~~~~Result:  [120.0, -120.0, 0.0, 0.0]
# ==============================Game 44=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 45=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 46=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 47=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 48=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 49=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 50=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 51=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2741.17647059 -1682.35294118  -566.66666667  -629.41176471]
# 结果M.S.E. [460.24730051 373.59714153 116.28845159 170.38062908]
# 自摸率： 43.750000
# 放铳率： 0.000000
# 和了率： 31.372549
# 副露率： 33.333333
# 平均打点：5956
# ~~~~~~~~~~~~Result:  [-5.0, -5.0, -5.0, 15.0]
# ==============================Game 52=============================
# ~~~~~~~~~~~~Result:  [106.0, -32.0, -32.0, -32.0]
# ==============================Game 53=============================
# ~~~~~~~~~~~~Result:  [26.0, -26.0, 0.0, 0.0]
# ==============================Game 54=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 55=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 56=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 57=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 58=============================
# ~~~~~~~~~~~~Result:  [90.0, -20.0, -40.0, -20.0]
# ==============================Game 59=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 60=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 61=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2729.50819672 -1559.01639344  -681.96721311  -603.27868852]
# 结果M.S.E. [424.93083531 325.13926935 121.2119263  166.37474195]
# 自摸率： 47.368421
# 放铳率： 0.000000
# 和了率： 31.147541
# 副露率： 37.704918
# 平均打点：6078
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 62=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 63=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 64=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 65=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 66=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 67=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 68=============================
# ~~~~~~~~~~~~Result:  [21.0, -7.0, -7.0, -7.0]
# ==============================Game 69=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 70=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 71=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2480.28169014 -1370.42253521  -673.23943662  -563.38028169]
# 结果M.S.E. [376.41023448 289.68509513 106.8931086  147.31935787]
# 自摸率： 50.000000
# 放铳率： 0.000000
# 和了率： 28.169014
# 副露率： 39.436620
# 平均打点：5880
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 72=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 73=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 74=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 75=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 76=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 77=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 78=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 79=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 80=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 81=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2346.91358025 -1262.96296296  -651.85185185  -555.55555556]
# 结果M.S.E. [336.94018606 256.6502732   95.91744264 130.61938433]
# 自摸率： 50.000000
# 放铳率： 0.000000
# 和了率： 24.691358
# 副露率： 41.975309
# 平均打点：5880
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 82=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 83=============================
# ~~~~~~~~~~~~Result:  [90.0, -20.0, -20.0, -40.0]
# ==============================Game 84=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 85=============================
# ~~~~~~~~~~~~Result:  [90.0, -80.0, 0.0, 0.0]
# ==============================Game 86=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 87=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 88=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 89=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 90=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 91=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2319.78021978 -1256.04395604  -624.17582418  -560.43956044]
# 结果M.S.E. [318.92836116 242.70647602  88.81868603 123.52625124]
# 自摸率： 50.000000
# 放铳率： 0.000000
# 和了率： 24.175824
# 副露率： 37.362637
# 平均打点：6072
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 92=============================
# ~~~~~~~~~~~~Result:  [250.0, -240.0, 0.0, 0.0]
# ==============================Game 93=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 94=============================
# ~~~~~~~~~~~~Result:  [62.0, -52.0, 0.0, 0.0]
# ==============================Game 95=============================
# ~~~~~~~~~~~~Result:  [40.0, -10.0, -10.0, -20.0]
# ==============================Game 96=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 97=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 98=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 99=============================
# ~~~~~~~~~~~~Result:  [42.0, -32.0, 0.0, 0.0]
# ==============================Game 100=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 101=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2500.         -1482.17821782  -592.07920792  -544.55445545]
# 结果M.S.E. [362.84663512 317.10506782  81.86967209 113.31747183]
# 自摸率： 46.153846
# 放铳率： 0.000000
# 和了率： 25.742574
# 副露率： 35.643564
# 平均打点：6538
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 102=============================
# ~~~~~~~~~~~~Result:  [90.0, -20.0, -40.0, -20.0]
# ==============================Game 103=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 104=============================
# ~~~~~~~~~~~~Result:  [120.0, -120.0, 0.0, 0.0]
# ==============================Game 105=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 106=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 107=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 108=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 109=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 110=============================
# ~~~~~~~~~~~~Result:  [49.0, -39.0, 0.0, 0.0]
# ==============================Game 111=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2517.11711712 -1518.91891892  -583.78378378  -522.52252252]
# 结果M.S.E. [349.29142943 306.27586895  82.0516538  104.92061213]
# 自摸率： 44.827586
# 放铳率： 0.000000
# 和了率： 26.126126
# 副露率： 35.135135
# 平均打点：6686
# ~~~~~~~~~~~~Result:  [11.0, -3.0, -3.0, -5.0]
# ==============================Game 112=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 113=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 114=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 115=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 116=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 117=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 118=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 119=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 120=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 121=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2359.50413223 -1412.39669421  -554.54545455  -500.        ]
# 结果M.S.E. [325.06471646 282.99859487  76.48982454  97.06434775]
# 自摸率： 46.666667
# 放铳率： 0.000000
# 和了率： 24.793388
# 副露率： 32.231405
# 平均打点：6500
# ~~~~~~~~~~~~Result:  [11.0, -5.0, -3.0, -3.0]
# ==============================Game 122=============================
# ~~~~~~~~~~~~Result:  [39.0, -39.0, 0.0, 0.0]
# ==============================Game 123=============================
# ~~~~~~~~~~~~Result:  [90.0, -80.0, 0.0, 0.0]
# ==============================Game 124=============================
# ~~~~~~~~~~~~Result:  [130.0, -120.0, 0.0, 0.0]
# ==============================Game 125=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 126=============================
# ~~~~~~~~~~~~Result:  [39.0, -39.0, 0.0, 0.0]
# ==============================Game 127=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 128=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 129=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 130=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 131=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2400.         -1520.61068702  -514.50381679  -464.1221374 ]
# 结果M.S.E. [315.27549293 280.44624998  71.72422678  90.34162449]
# 自摸率： 42.857143
# 放铳率： 0.000000
# 和了率： 26.717557
# 副露率： 32.061069
# 平均打点：6397
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 132=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 133=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 134=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 135=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 136=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 137=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 138=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 139=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 140=============================
# ~~~~~~~~~~~~Result:  [190.0, -60.0, -60.0, -60.0]
# ==============================Game 141=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2400.         -1469.5035461   -534.75177305  -487.94326241]
# 结果M.S.E. [316.39314548 264.0488362   77.8979522   93.20495589]
# 自摸率： 44.444444
# 放铳率： 0.000000
# 和了率： 25.531915
# 副露率： 31.914894
# 平均打点：6719
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 142=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 143=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 144=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 145=============================
# ~~~~~~~~~~~~Result:  [10.0, -10.0, 0.0, 0.0]
# ==============================Game 146=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 147=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 148=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 149=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 150=============================
# ~~~~~~~~~~~~Result:  [20.0, -5.0, -10.0, -5.0]
# ==============================Game 151=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2347.01986755 -1415.23178808  -539.07284768  -492.05298013]
# 结果M.S.E. [296.94851439 247.29890024  73.47098491  87.6002658 ]
# 自摸率： 46.153846
# 放铳率： 0.000000
# 和了率： 25.827815
# 副露率： 32.450331
# 平均打点：6356
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 152=============================
# ~~~~~~~~~~~~Result:  [118.0, -36.0, -36.0, -36.0]
# ==============================Game 153=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 154=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 155=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 156=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 157=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 158=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 159=============================
# ~~~~~~~~~~~~Result:  [26.0, -26.0, 0.0, 0.0]
# ==============================Game 160=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 161=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2284.47204969 -1365.83850932  -527.95031056  -483.85093168]
# 结果M.S.E. [286.35569242 233.74529398  72.17921095  84.89072633]
# 自摸率： 46.341463
# 放铳率： 0.000000
# 和了率： 25.465839
# 副露率： 31.677019
# 平均打点：6373
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 162=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 163=============================
# ~~~~~~~~~~~~Result:  [36.0, -26.0, 0.0, 0.0]
# ==============================Game 164=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 165=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 166=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 167=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 168=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 169=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 170=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 171=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2230.40935673 -1324.56140351  -520.46783626  -478.94736842]
# 结果M.S.E. [271.33632468 220.93632589  68.59785289  80.45223961]
# 自摸率： 45.238095
# 放铳率： 0.000000
# 和了率： 24.561404
# 副露率： 30.409357
# 平均打点：6283
# ~~~~~~~~~~~~Result:  [50.0, -10.0, -10.0, -20.0]
# ==============================Game 172=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 173=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 174=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 175=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 176=============================
# ~~~~~~~~~~~~Result:  [118.0, -36.0, -36.0, -36.0]
# ==============================Game 177=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 178=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 179=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 180=============================
# ~~~~~~~~~~~~Result:  [60.0, -20.0, -20.0, -20.0]
# ==============================Game 181=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2238.67403315 -1293.37016575  -533.70165746  -500.        ]
# 结果M.S.E. [263.46289002 209.91073032  67.96353096  79.14256168]
# 自摸率： 50.000000
# 放铳率： 0.000000
# 和了率： 25.414365
# 副露率： 29.834254
# 平均打点：6254
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 182=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 183=============================
# ~~~~~~~~~~~~Result:  [130.0, -30.0, -30.0, -60.0]
# ==============================Game 184=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 185=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 186=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 187=============================
# ~~~~~~~~~~~~Result:  [36.0, -26.0, 0.0, 0.0]
# ==============================Game 188=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 189=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 190=============================
# ~~~~~~~~~~~~Result:  [40.0, -10.0, -20.0, -10.0]
# ==============================Game 191=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2245.02617801 -1270.68062827  -542.40837696  -520.94240838]
# 结果M.S.E. [256.39662235 199.82420192  66.5738238   80.70578826]
# 自摸率： 51.020408
# 放铳率： 0.000000
# 和了率： 25.654450
# 副露率： 30.366492
# 平均打点：6251
# ~~~~~~~~~~~~Result:  [170.0, -40.0, -40.0, -80.0]
# ==============================Game 192=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 193=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 194=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 195=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 196=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 197=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 198=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 199=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 200=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 201=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2242.78606965 -1237.31343284  -545.27363184  -544.7761194 ]
# 结果M.S.E. [254.84353065 191.09595534  66.02460738  85.56592233]
# 自摸率： 52.000000
# 放铳率： 0.000000
# 和了率： 24.875622
# 副露率： 28.855721
# 平均打点：6446
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 202=============================
# ~~~~~~~~~~~~Result:  [15.0, -4.0, -7.0, -4.0]
# ==============================Game 203=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 204=============================
# ~~~~~~~~~~~~Result:  [15.0, -5.0, -5.0, -5.0]
# ==============================Game 205=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 206=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 207=============================
# ~~~~~~~~~~~~Result:  [52.0, -52.0, 0.0, 0.0]
# ==============================Game 208=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 209=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 210=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 211=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2203.79146919 -1217.06161137  -534.5971564   -532.7014218 ]
# 结果M.S.E. [244.41732732 183.5524024   63.28699223  81.81148579]
# 自摸率： 52.830189
# 放铳率： 0.000000
# 和了率： 25.118483
# 副露率： 29.857820
# 平均打点：6235
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 212=============================
# ~~~~~~~~~~~~Result:  [29.0, -29.0, 0.0, 0.0]
# ==============================Game 213=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -5.0, -5.0]
# ==============================Game 214=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 215=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 216=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 217=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 218=============================
# ~~~~~~~~~~~~Result:  [11.0, -3.0, -5.0, -3.0]
# ==============================Game 219=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 220=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 221=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2140.27149321 -1190.04524887  -523.98190045  -503.16742081]
# 结果M.S.E. [234.93322409 175.89173537  60.78236869  79.95716882]
# 自摸率： 53.571429
# 放铳率： 0.000000
# 和了率： 25.339367
# 副露率： 30.769231
# 平均打点：6008
# ~~~~~~~~~~~~Result:  [80.0, -80.0, 0.0, 0.0]
# ==============================Game 222=============================
# ~~~~~~~~~~~~Result:  [11.0, -3.0, -5.0, -3.0]
# ==============================Game 223=============================
# ~~~~~~~~~~~~Result:  [130.0, -30.0, -30.0, -60.0]
# ==============================Game 224=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 225=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 226=============================
# ~~~~~~~~~~~~Result:  [20.0, -5.0, -10.0, -5.0]
# ==============================Game 227=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 228=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 229=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 230=============================
# ~~~~~~~~~~~~Result:  [79.0, -20.0, -39.0, -20.0]
# ==============================Game 231=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2216.45021645 -1211.25541126  -550.64935065  -532.46753247]
# 结果M.S.E. [231.94971185 171.28042135  61.15052324  80.52954523]
# 自摸率： 55.737705
# 放铳率： 0.000000
# 和了率： 26.406926
# 副露率： 31.601732
# 平均打点：6024
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 232=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 233=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 234=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 235=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 236=============================
# ~~~~~~~~~~~~Result:  [116.0, -116.0, 0.0, 0.0]
# ==============================Game 237=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 238=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 239=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 240=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 241=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2205.80912863 -1209.12863071  -544.39834025  -526.97095436]
# 结果M.S.E. [227.10525233 171.01174947  58.99634876  77.47396774]
# 自摸率： 55.555556
# 放铳率： 0.000000
# 和了率： 26.141079
# 副露率： 32.365145
# 平均打点：6065
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 242=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 243=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 244=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 245=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 246=============================
# ~~~~~~~~~~~~Result:  [90.0, -20.0, -40.0, -20.0]
# ==============================Game 247=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 248=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 249=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 250=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 251=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2205.57768924 -1188.84462151  -558.56573705  -533.86454183]
# 结果M.S.E. [220.07155257 164.5166899   58.59000008  74.85398997]
# 自摸率： 56.250000
# 放铳率： 0.000000
# 和了率： 25.498008
# 副露率： 32.669323
# 平均打点：6095
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 252=============================
# ~~~~~~~~~~~~Result:  [29.0, -29.0, 0.0, 0.0]
# ==============================Game 253=============================
# ~~~~~~~~~~~~Result:  [20.0, -10.0, -5.0, -5.0]
# ==============================Game 254=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 255=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 256=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 257=============================
# ~~~~~~~~~~~~Result:  [26.0, -26.0, 0.0, 0.0]
# ==============================Game 258=============================
# ~~~~~~~~~~~~Result:  [90.0, -80.0, 0.0, 0.0]
# ==============================Game 259=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 260=============================
# ~~~~~~~~~~~~Result:  [120.0, -120.0, 0.0, 0.0]
# ==============================Game 261=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2245.59386973 -1256.32183908  -550.57471264  -511.49425287]
# 结果M.S.E. [216.81448433 165.91153498  56.66256229  73.44993645]
# 自摸率： 53.623188
# 放铳率： 0.000000
# 和了率： 26.436782
# 副露率： 32.950192
# 平均打点：6052
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 262=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 263=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 264=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 265=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 266=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 267=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 268=============================
# ~~~~~~~~~~~~Result:  [190.0, -60.0, -60.0, -60.0]
# ==============================Game 269=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 270=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 29.0, -29.0]
# ==============================Game 271=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2262.36162362 -1243.17343173  -552.76752768  -536.53136531]
# 结果M.S.E. [217.75457991 161.15219082  59.77807666  74.27782504]
# 自摸率： 54.285714
# 放铳率： 0.000000
# 和了率： 25.830258
# 副露率： 33.948339
# 平均打点：6222
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 272=============================
# ~~~~~~~~~~~~Result:  [190.0, -60.0, -60.0, -60.0]
# ==============================Game 273=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -5.0, -5.0]
# ==============================Game 274=============================
# ~~~~~~~~~~~~Result:  [40.0, -10.0, -20.0, -10.0]
# ==============================Game 275=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 276=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 277=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 278=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 279=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 280=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 281=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2292.17081851 -1238.07829181  -574.02135231  -554.80427046]
# 结果M.S.E. [218.04299143 156.59829122  61.21620798  74.38965435]
# 自摸率： 56.164384
# 放铳率： 0.000000
# 和了率： 25.978648
# 副露率： 33.096085
# 平均打点：6295
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 282=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 283=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 284=============================
# ~~~~~~~~~~~~Result:  [118.0, -36.0, -36.0, -36.0]
# ==============================Game 285=============================
# ~~~~~~~~~~~~Result:  [11.0, -5.0, -3.0, -3.0]
# ==============================Game 286=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 287=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 288=============================
# ~~~~~~~~~~~~Result:  [15.0, -5.0, -5.0, -5.0]
# ==============================Game 289=============================
# ~~~~~~~~~~~~Result:  [49.0, -39.0, 0.0, 0.0]
# ==============================Game 290=============================
# ~~~~~~~~~~~~Result:  [130.0, -30.0, -60.0, -30.0]
# ==============================Game 291=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2331.27147766 -1245.36082474  -593.47079038  -564.604811  ]
# 结果M.S.E. [215.73491865 152.0765612   63.01862041  73.21970391]
# 自摸率： 56.962025
# 放铳率： 0.000000
# 和了率： 27.147766
# 副露率： 33.333333
# 平均打点：6213
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 292=============================
# ~~~~~~~~~~~~Result:  [15.0, -5.0, -5.0, -5.0]
# ==============================Game 293=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 294=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 295=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 296=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 297=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 298=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 299=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 300=============================
# ~~~~~~~~~~~~Result:  [130.0, -40.0, -40.0, -40.0]
# ==============================Game 301=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2338.53820598 -1232.22591362  -601.99335548  -574.08637874]
# 结果M.S.E. [211.65875315 147.56880507  62.15011924  71.85593191]
# 自摸率： 58.024691
# 放铳率： 0.000000
# 和了率： 26.910299
# 副露率： 33.222591
# 平均打点：6227
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 302=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 303=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 304=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 305=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 306=============================
# ~~~~~~~~~~~~Result:  [50.0, -10.0, -20.0, -10.0]
# ==============================Game 307=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 308=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 309=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 310=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 311=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2311.5755627  -1208.68167203  -601.92926045  -571.70418006]
# 结果M.S.E. [205.64148558 143.10186559  60.52868629  69.73497432]
# 自摸率： 58.536585
# 放铳率： 0.000000
# 和了率： 26.366559
# 副露率： 33.440514
# 平均打点：6200
# ~~~~~~~~~~~~Result:  [170.0, -160.0, 0.0, 0.0]
# ==============================Game 312=============================
# ~~~~~~~~~~~~Result:  [-10.0, 30.0, -10.0, -10.0]
# ==============================Game 313=============================
# ~~~~~~~~~~~~Result:  [79.0, -39.0, -20.0, -20.0]
# ==============================Game 314=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 315=============================
# ~~~~~~~~~~~~Result:  [80.0, -20.0, -20.0, -40.0]
# ==============================Game 316=============================
# ~~~~~~~~~~~~Result:  [39.0, -29.0, 0.0, 0.0]
# ==============================Game 317=============================
# ~~~~~~~~~~~~Result:  [50.0, -20.0, -10.0, -10.0]
# ==============================Game 318=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 319=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 320=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 321=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2382.24299065 -1254.51713396  -611.21495327  -588.16199377]
# 结果M.S.E. [205.70395134 147.09315646  59.11781348  68.67410403]
# 自摸率： 58.620690
# 放铳率： 0.000000
# 和了率： 27.102804
# 副露率： 33.021807
# 平均打点：6289
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 322=============================
# ~~~~~~~~~~~~Result:  [80.0, -20.0, -40.0, -20.0]
# ==============================Game 323=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 324=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 325=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 326=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 327=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 328=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 329=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 330=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 331=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2355.58912387 -1237.76435045  -607.85498489  -591.5407855 ]
# 结果M.S.E. [200.99462341 142.87564364  59.41297715  66.88799334]
# 自摸率： 59.090909
# 放铳率： 0.000000
# 和了率： 26.586103
# 副露率： 32.326284
# 平均打点：6309
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 332=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 333=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 334=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 335=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 336=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 337=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 338=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 339=============================
# ~~~~~~~~~~~~Result:  [11.0, -3.0, -3.0, -5.0]
# ==============================Game 340=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 341=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2321.9941349  -1214.07624633  -602.63929619  -587.39002933]
# 结果M.S.E. [195.76718618 138.95133835  57.86033182  65.08650675]
# 自摸率： 59.550562
# 放铳率： 0.000000
# 和了率： 26.099707
# 副露率： 31.964809
# 平均打点：6250
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 342=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 343=============================
# ...
# ==============================Game 19886=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19887=============================
# ~~~~~~~~~~~~Result:  [11.0, -3.0, -3.0, -5.0]
# ==============================Game 19888=============================
# ~~~~~~~~~~~~Result:  [40.0, -10.0, -10.0, -10.0]
# ==============================Game 19889=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19890=============================
# ~~~~~~~~~~~~Result:  [20.0, -5.0, -10.0, -5.0]
# ==============================Game 19891=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2258.76527073 -1194.43969635  -582.0572118   -580.6042934 ]
# 结果M.S.E. [22.47832486 15.64096771  7.73321327  7.94365321]
# 自摸率： 56.940312
# 放铳率： 0.105575
# 和了率： 28.721532
# 副露率： 33.955055
# 平均打点：5208
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19892=============================
# ~~~~~~~~~~~~Result:  [29.0, -29.0, 0.0, 0.0]
# ==============================Game 19893=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19894=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19895=============================
# ~~~~~~~~~~~~Result:  [40.0, -10.0, -10.0, -20.0]
# ==============================Game 19896=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19897=============================
# ~~~~~~~~~~~~Result:  [79.0, -39.0, -20.0, -20.0]
# ==============================Game 19898=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19899=============================
# ~~~~~~~~~~~~Result:  [10.0, -10.0, 0.0, 0.0]
# ==============================Game 19900=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19901=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2258.57494598 -1194.33194312  -581.96573037  -580.56379076]
# 结果M.S.E. [22.47056455 15.63451951  7.73010017  7.94070543]
# 自摸率： 56.935456
# 放铳率： 0.105522
# 和了率： 28.727200
# 副露率： 33.963117
# 平均打点：5207
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19902=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19903=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19904=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19905=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19906=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19907=============================
# ~~~~~~~~~~~~Result:  [90.0, -20.0, -20.0, -40.0]
# ==============================Game 19908=============================
# ~~~~~~~~~~~~Result:  [70.0, -20.0, -20.0, -20.0]
# ==============================Game 19909=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19910=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19911=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2258.59575109 -1194.13389584  -582.07523479  -580.77444629]
# 结果M.S.E. [22.46310383 15.6272447   7.72720947  7.93922105]
# 自摸率： 56.942987
# 放铳率： 0.105469
# 和了率： 28.717794
# 副露率： 33.956105
# 平均打点：5207
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19912=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19913=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19914=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19915=============================
# ~~~~~~~~~~~~Result:  [20.0, -5.0, -5.0, -10.0]
# ==============================Game 19916=============================
# ~~~~~~~~~~~~Result:  [49.0, -39.0, 0.0, 0.0]
# ==============================Game 19917=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19918=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19919=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19920=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19921=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2258.2601275  -1193.9561267   -582.00893529  -580.7338989 ]
# 结果M.S.E. [22.45319679 15.62050173  7.72372194  7.93564299]
# 自摸率： 56.940559
# 放铳率： 0.105416
# 和了率： 28.713418
# 副露率： 33.949099
# 平均打点：5206
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19922=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19923=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19924=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19925=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19926=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19927=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19928=============================
# ~~~~~~~~~~~~Result:  [39.0, -39.0, 0.0, 0.0]
# ==============================Game 19929=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19930=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19931=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2257.8746676  -1193.7534494   -581.91761577  -580.64321911]
# 结果M.S.E. [22.44360869 15.61384143  7.72029199  7.93209408]
# 自摸率： 56.930607
# 放铳率： 0.105364
# 和了率： 28.704029
# 副露率： 33.952135
# 平均打点：5206
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19932=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19933=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19934=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19935=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19936=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19937=============================
# ~~~~~~~~~~~~Result:  [39.0, -39.0, 0.0, 0.0]
# ==============================Game 19938=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 19939=============================
# ~~~~~~~~~~~~Result:  [36.0, -26.0, 0.0, 0.0]
# ==============================Game 19940=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19941=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2257.59490497 -1193.60613811  -581.90160975  -580.62785216]
# 结果M.S.E. [22.43344281 15.60770192  7.71694759  7.92862926]
# 自摸率： 56.910711
# 放铳率： 0.105311
# 和了率： 28.699664
# 副露率： 33.955168
# 平均打点：5205
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19942=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19943=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 19944=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19945=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19946=============================
# ~~~~~~~~~~~~Result:  [15.0, 15.0, -15.0, -15.0]
# ==============================Game 19947=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19948=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19949=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19950=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19951=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2256.73901058 -1193.08305348  -581.73525137  -580.46213222]
# 结果M.S.E. [22.42423594 15.60132105  7.71368643  7.92524447]
# 自摸率： 56.900769
# 放铳率： 0.105258
# 和了率： 28.690291
# 副露率： 33.953185
# 平均打点：5205
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 19952=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19953=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 19954=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19955=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 19956=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19957=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19958=============================
# ~~~~~~~~~~~~Result:  [40.0, -10.0, -20.0, -10.0]
# ==============================Game 19959=============================
# ~~~~~~~~~~~~Result:  [20.0, -5.0, -5.0, -10.0]
# ==============================Game 19960=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19961=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2256.10941336 -1192.81098141  -581.61915736  -580.22143179]
# 结果M.S.E. [22.41514542 15.59402605  7.71276131  7.92297017]
# 自摸率： 56.915823
# 放铳率： 0.105205
# 和了率： 28.685938
# 副露率： 33.956215
# 平均打点：5204
# ~~~~~~~~~~~~Result:  [52.0, -26.0, -13.0, -13.0]
# ==============================Game 19962=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19963=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19964=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19965=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19966=============================
# ~~~~~~~~~~~~Result:  [74.0, -64.0, 0.0, 0.0]
# ==============================Game 19967=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 19968=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19969=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19970=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19971=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2255.81092584 -1192.81458114  -581.44309248  -580.0460668 ]
# 结果M.S.E. [22.40711059 15.58929961  7.70945169  7.91953909]
# 自摸率： 56.903474
# 放铳率： 0.105152
# 和了率： 28.686596
# 副露率： 33.954234
# 平均打点：5204
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19972=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19973=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19974=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19975=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19976=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19977=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19978=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19979=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19980=============================
# ~~~~~~~~~~~~Result:  [96.0, -32.0, -32.0, -32.0]
# ==============================Game 19981=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2255.56278465 -1192.52790151  -581.46238927  -580.06606276]
# 结果M.S.E. [22.40068492 15.58251633  7.70712268  7.91706455]
# 自摸率： 56.918513
# 放铳率： 0.105100
# 和了率： 28.682248
# 副露率： 33.942245
# 平均打点：5204
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19982=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, -10.0, 30.0]
# ==============================Game 19983=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19984=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19985=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19986=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19987=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19988=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19989=============================
# ~~~~~~~~~~~~Result:  [15.0, -15.0, -15.0, 15.0]
# ==============================Game 19990=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19991=============================
# ------------------------- Statistics ----------------------
# 平均结果: [ 2254.70961933 -1192.20649292  -581.44665099  -579.70086539]
# 结果M.S.E. [22.39167551 15.57531209  7.70379277  7.9161634 ]
# 自摸率： 56.918513
# 放铳率： 0.105047
# 和了率： 28.667901
# 副露率： 33.925266
# 平均打点：5204
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19992=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19993=============================
# ~~~~~~~~~~~~Result:  [-10.0, -10.0, 30.0, -10.0]
# ==============================Game 19994=============================
# ~~~~~~~~~~~~Result:  [23.0, -13.0, 0.0, 0.0]
# ==============================Game 19995=============================
# ~~~~~~~~~~~~Result:  [20.0, -20.0, 0.0, 0.0]
# ==============================Game 19996=============================
# ~~~~~~~~~~~~Result:  [30.0, -10.0, -10.0, -10.0]
# ==============================Game 19997=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]
# ==============================Game 19998=============================
# ~~~~~~~~~~~~Result:  [30.0, -20.0, 0.0, 0.0]
# ==============================Game 19999=============================
# ~~~~~~~~~~~~Result:  [0.0, 0.0, 0.0, 0.0]

# %%
total_results_array = np.array(total_results)
sampled_games = np.zeros([100000, 8, 4])
for i in range(100000):
    sampled_games[i] = total_results_array[np.random.choice(len(total_results_array), 8)]
sampled_match_results = sampled_games.sum(-2)

win_rate = ((sampled_games[:, :, 0] + sampled_games[:, :, 1]).sum(1) > (sampled_games[:, :, 2] + sampled_games[:, :, 3]).sum(1)).mean(0) 
print(win_rate)
# Out:
# 0.56003

# %%
for pid in range(4):
    print(np.mean(np.argmax(sampled_match_results, axis=-1) == pid) * 100, np.std(np.argmax(sampled_match_results, axis=-1) == pid) / 100000 ** 0.5 * 100)
# Out:
# 27.923 0.14186634805337026
# 28.502 0.1427527931775767
# 22.076999999999998 0.1311604388144535
# 21.498 0.1299090449506885

# %%
np.array(total_results).std(axis=0) * 100 / np.sqrt(game)

# %%
to_unicode_tails(env_test.hand_tiles[3])

# %%
plt.pcolor(env_test.get_obs(3)[:6, :])
plt.show()

# %%
env_test.can_riichi_tiles_id

# %%
for act in env_test.t.get_self_actions():
    print(act.action)
    print(int(act.correspond_tiles[0].tile))

# %%
env_test.riichi_tile_id

# %%
int(env_test.t.get_selected_action_tile().tile)

# %%
env_test.t.get_response_actions()[0].action

# %%
env_test.t.players[curr_pid].hand.__len__()

# %%
env_test.Phases[env_test.t.get_phase()]

# %%
env_test.hand_tiles[curr_pid]

# %%
env_test.can_riichi

# %%
env_test.t.get_self_actions()[0].action

# %%
a = set([1,2,3,4,4])

# %%
list(a)

# %%
mp.Action.Kakan
